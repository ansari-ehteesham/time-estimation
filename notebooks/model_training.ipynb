# %%
from google.colab import drive

drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !unzip /content/drive/MyDrive/data_preprocessed.zip
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: data_preprocessed/val/1351.png
#   inflating: data_preprocessed/val/1352.png
#   inflating: data_preprocessed/val/13528.png
#   inflating: data_preprocessed/val/1353.png
#   inflating: data_preprocessed/val/13543.png
#   inflating: data_preprocessed/val/13545.png
#   inflating: data_preprocessed/val/1355.png
#   inflating: data_preprocessed/val/13554.png
#   inflating: data_preprocessed/val/13556.png
#   inflating: data_preprocessed/val/13580.png
#   inflating: data_preprocessed/val/13585.png
#   inflating: data_preprocessed/val/13596.png
#   inflating: data_preprocessed/val/13621.png
#   inflating: data_preprocessed/val/13634.png
#   inflating: data_preprocessed/val/13647.png
#   inflating: data_preprocessed/val/13652.png
#   inflating: data_preprocessed/val/13658.png
#   inflating: data_preprocessed/val/13667.png
#   inflating: data_preprocessed/val/13671.png
#   inflating: data_preprocessed/val/13677.png
#   inflating: data_preprocessed/val/13678.png
#   inflating: data_preprocessed/val/13688.png
#   inflating: data_preprocessed/val/13691.png
#   inflating: data_preprocessed/val/13696.png
#   inflating: data_preprocessed/val/13718.png
#   inflating: data_preprocessed/val/1372.png
#   inflating: data_preprocessed/val/13721.png
#   inflating: data_preprocessed/val/13722.png
#   inflating: data_preprocessed/val/13726.png
#   inflating: data_preprocessed/val/13727.png
#   inflating: data_preprocessed/val/1376.png
#   inflating: data_preprocessed/val/13779.png
#   inflating: data_preprocessed/val/1378.png
#   inflating: data_preprocessed/val/13781.png
#   inflating: data_preprocessed/val/13783.png
#   inflating: data_preprocessed/val/1380.png
#   inflating: data_preprocessed/val/13811.png
#   inflating: data_preprocessed/val/13812.png
#   inflating: data_preprocessed/val/13824.png
#   inflating: data_preprocessed/val/1385.png
#   inflating: data_preprocessed/val/13851.png
#   inflating: data_preprocessed/val/13857.png
#   inflating: data_preprocessed/val/13865.png
#   inflating: data_preprocessed/val/13869.png
#   inflating: data_preprocessed/val/13886.png
#   inflating: data_preprocessed/val/13898.png
#   inflating: data_preprocessed/val/13899.png
#   inflating: data_preprocessed/val/13907.png
#   inflating: data_preprocessed/val/13909.png
#   inflating: data_preprocessed/val/13921.png
#   inflating: data_preprocessed/val/13930.png
#   inflating: data_preprocessed/val/13935.png
#   inflating: data_preprocessed/val/13945.png
#   inflating: data_preprocessed/val/13947.png
#   inflating: data_preprocessed/val/13950.png
#   inflating: data_preprocessed/val/13951.png
#   inflating: data_preprocessed/val/13955.png
#   inflating: data_preprocessed/val/13957.png
#   inflating: data_preprocessed/val/13959.png
#   inflating: data_preprocessed/val/13969.png
#   inflating: data_preprocessed/val/13983.png
#   inflating: data_preprocessed/val/13995.png
#   inflating: data_preprocessed/val/13998.png
#   inflating: data_preprocessed/val/14004.png
#   inflating: data_preprocessed/val/1401.png
#   inflating: data_preprocessed/val/14015.png
#   inflating: data_preprocessed/val/14025.png
#   inflating: data_preprocessed/val/14038.png
#   inflating: data_preprocessed/val/14056.png
#   inflating: data_preprocessed/val/1406.png
#   inflating: data_preprocessed/val/14069.png
#   inflating: data_preprocessed/val/14078.png
#   inflating: data_preprocessed/val/14079.png
#   inflating: data_preprocessed/val/14092.png
#   inflating: data_preprocessed/val/14098.png
#   inflating: data_preprocessed/val/141.png
#   inflating: data_preprocessed/val/14102.png
#   inflating: data_preprocessed/val/14108.png
#   inflating: data_preprocessed/val/14109.png
#   inflating: data_preprocessed/val/14117.png
#   inflating: data_preprocessed/val/14120.png
#   inflating: data_preprocessed/val/14127.png
#   inflating: data_preprocessed/val/14129.png
#   inflating: data_preprocessed/val/14136.png
#   inflating: data_preprocessed/val/14142.png
#   inflating: data_preprocessed/val/14145.png
#   inflating: data_preprocessed/val/14149.png
#   inflating: data_preprocessed/val/14158.png
#   inflating: data_preprocessed/val/14159.png
#   inflating: data_preprocessed/val/14161.png
#   inflating: data_preprocessed/val/14167.png
#   inflating: data_preprocessed/val/14168.png
#   inflating: data_preprocessed/val/14191.png
#   inflating: data_preprocessed/val/14199.png
#   inflating: data_preprocessed/val/14212.png
#   inflating: data_preprocessed/val/14214.png
#   inflating: data_preprocessed/val/14217.png
#   inflating: data_preprocessed/val/14225.png
#   inflating: data_preprocessed/val/14226.png
#   inflating: data_preprocessed/val/14227.png
#   inflating: data_preprocessed/val/14233.png
#   inflating: data_preprocessed/val/14239.png
#   inflating: data_preprocessed/val/1425.png
#   inflating: data_preprocessed/val/14253.png
#   inflating: data_preprocessed/val/14265.png
#   inflating: data_preprocessed/val/14268.png
#   inflating: data_preprocessed/val/14270.png
#   inflating: data_preprocessed/val/14272.png
#   inflating: data_preprocessed/val/14273.png
#   inflating: data_preprocessed/val/14280.png
#   inflating: data_preprocessed/val/14309.png
#   inflating: data_preprocessed/val/14314.png
#   inflating: data_preprocessed/val/14325.png
#   inflating: data_preprocessed/val/14327.png
#   inflating: data_preprocessed/val/1433.png
#   inflating: data_preprocessed/val/14341.png
#   inflating: data_preprocessed/val/14354.png
#   inflating: data_preprocessed/val/1436.png
#   inflating: data_preprocessed/val/14368.png
#   inflating: data_preprocessed/val/14371.png
#   inflating: data_preprocessed/val/1439.png
#   inflating: data_preprocessed/val/14410.png
#   inflating: data_preprocessed/val/14419.png
#   inflating: data_preprocessed/val/14424.png
#   inflating: data_preprocessed/val/14444.png
#   inflating: data_preprocessed/val/14458.png
#   inflating: data_preprocessed/val/14461.png
#   inflating: data_preprocessed/val/14475.png
#   inflating: data_preprocessed/val/14478.png
#   inflating: data_preprocessed/val/14487.png
#   inflating: data_preprocessed/val/14489.png
#   inflating: data_preprocessed/val/14503.png
#   inflating: data_preprocessed/val/14506.png
#   inflating: data_preprocessed/val/14509.png
#   inflating: data_preprocessed/val/14513.png
#   inflating: data_preprocessed/val/14515.png
#   inflating: data_preprocessed/val/14527.png
#   inflating: data_preprocessed/val/14533.png
#   inflating: data_preprocessed/val/14559.png
#   inflating: data_preprocessed/val/14561.png
#   inflating: data_preprocessed/val/14563.png
#   inflating: data_preprocessed/val/14586.png
#   inflating: data_preprocessed/val/14593.png
#   inflating: data_preprocessed/val/14595.png
#   inflating: data_preprocessed/val/14598.png
#   inflating: data_preprocessed/val/14601.png
#   inflating: data_preprocessed/val/14605.png
#   inflating: data_preprocessed/val/14612.png
#   inflating: data_preprocessed/val/1462.png
#   inflating: data_preprocessed/val/14623.png
#   inflating: data_preprocessed/val/14629.png
#   inflating: data_preprocessed/val/1463.png
#   inflating: data_preprocessed/val/14637.png
#   inflating: data_preprocessed/val/14647.png
#   inflating: data_preprocessed/val/14666.png
#   inflating: data_preprocessed/val/14677.png
#   inflating: data_preprocessed/val/14680.png
#   inflating: data_preprocessed/val/14693.png
#   inflating: data_preprocessed/val/14698.png
#   inflating: data_preprocessed/val/14702.png
#   inflating: data_preprocessed/val/14707.png
#   inflating: data_preprocessed/val/14721.png
#   inflating: data_preprocessed/val/14733.png
#   inflating: data_preprocessed/val/14739.png
#   inflating: data_preprocessed/val/14742.png
#   inflating: data_preprocessed/val/14743.png
#   inflating: data_preprocessed/val/14749.png
#   inflating: data_preprocessed/val/14775.png
#   inflating: data_preprocessed/val/14781.png
#   inflating: data_preprocessed/val/14787.png
#   inflating: data_preprocessed/val/1479.png
#   inflating: data_preprocessed/val/14791.png
#   inflating: data_preprocessed/val/14796.png
#   inflating: data_preprocessed/val/14807.png
#   inflating: data_preprocessed/val/14821.png
#   inflating: data_preprocessed/val/14831.png
#   inflating: data_preprocessed/val/14838.png
#   inflating: data_preprocessed/val/14847.png
#   inflating: data_preprocessed/val/14850.png
#   inflating: data_preprocessed/val/14856.png
#   inflating: data_preprocessed/val/14859.png
#   inflating: data_preprocessed/val/14862.png
#   inflating: data_preprocessed/val/14870.png
#   inflating: data_preprocessed/val/14874.png
#   inflating: data_preprocessed/val/14882.png
#   inflating: data_preprocessed/val/14888.png
#   inflating: data_preprocessed/val/14898.png
#   inflating: data_preprocessed/val/14912.png
#   inflating: data_preprocessed/val/14916.png
#   inflating: data_preprocessed/val/14917.png
#   inflating: data_preprocessed/val/14919.png
#   inflating: data_preprocessed/val/14921.png
#   inflating: data_preprocessed/val/14925.png
#   inflating: data_preprocessed/val/14957.png
#   inflating: data_preprocessed/val/14963.png
#   inflating: data_preprocessed/val/14965.png
#   inflating: data_preprocessed/val/14967.png
#   inflating: data_preprocessed/val/14972.png
#   inflating: data_preprocessed/val/14975.png
#   inflating: data_preprocessed/val/14982.png
#   inflating: data_preprocessed/val/14987.png
#   inflating: data_preprocessed/val/14994.png
#   inflating: data_preprocessed/val/14999.png
#   inflating: data_preprocessed/val/1502.png
#   inflating: data_preprocessed/val/15023.png
#   inflating: data_preprocessed/val/15036.png
#   inflating: data_preprocessed/val/15037.png
#   inflating: data_preprocessed/val/15064.png
#   inflating: data_preprocessed/val/15069.png
#   inflating: data_preprocessed/val/15074.png
#   inflating: data_preprocessed/val/15077.png
#   inflating: data_preprocessed/val/15089.png
#   inflating: data_preprocessed/val/15094.png
#   inflating: data_preprocessed/val/15096.png
#   inflating: data_preprocessed/val/15114.png
#   inflating: data_preprocessed/val/15116.png
#   inflating: data_preprocessed/val/15120.png
#   inflating: data_preprocessed/val/15123.png
#   inflating: data_preprocessed/val/15126.png
#   inflating: data_preprocessed/val/15131.png
#   inflating: data_preprocessed/val/15135.png
#   inflating: data_preprocessed/val/15136.png
#   inflating: data_preprocessed/val/15138.png
#   inflating: data_preprocessed/val/15143.png
#   inflating: data_preprocessed/val/15150.png
#   inflating: data_preprocessed/val/15151.png
#   inflating: data_preprocessed/val/15153.png
#   inflating: data_preprocessed/val/15160.png
#   inflating: data_preprocessed/val/15164.png
#   inflating: data_preprocessed/val/15169.png
#   inflating: data_preprocessed/val/15175.png
#   inflating: data_preprocessed/val/15181.png
#   inflating: data_preprocessed/val/15186.png
#   inflating: data_preprocessed/val/152.png
#   inflating: data_preprocessed/val/15202.png
#   inflating: data_preprocessed/val/15218.png
#   inflating: data_preprocessed/val/15222.png
#   inflating: data_preprocessed/val/15228.png
#   inflating: data_preprocessed/val/15229.png
#   inflating: data_preprocessed/val/15248.png
#   inflating: data_preprocessed/val/15249.png
#   inflating: data_preprocessed/val/15252.png
#   inflating: data_preprocessed/val/15272.png
#   inflating: data_preprocessed/val/1528.png
#   inflating: data_preprocessed/val/15292.png
#   inflating: data_preprocessed/val/15302.png
#   inflating: data_preprocessed/val/15311.png
#   inflating: data_preprocessed/val/15317.png
#   inflating: data_preprocessed/val/15321.png
#   inflating: data_preprocessed/val/1533.png
#   inflating: data_preprocessed/val/15330.png
#   inflating: data_preprocessed/val/15337.png
#   inflating: data_preprocessed/val/15370.png
#   inflating: data_preprocessed/val/1538.png
#   inflating: data_preprocessed/val/15389.png
#   inflating: data_preprocessed/val/15393.png
#   inflating: data_preprocessed/val/15394.png
#   inflating: data_preprocessed/val/15401.png
#   inflating: data_preprocessed/val/1541.png
#   inflating: data_preprocessed/val/15412.png
#   inflating: data_preprocessed/val/15434.png
#   inflating: data_preprocessed/val/15436.png
#   inflating: data_preprocessed/val/15449.png
#   inflating: data_preprocessed/val/15450.png
#   inflating: data_preprocessed/val/15451.png
#   inflating: data_preprocessed/val/15465.png
#   inflating: data_preprocessed/val/15471.png
#   inflating: data_preprocessed/val/15473.png
#   inflating: data_preprocessed/val/15477.png
#   inflating: data_preprocessed/val/15485.png
#   inflating: data_preprocessed/val/15495.png
#   inflating: data_preprocessed/val/1551.png
#   inflating: data_preprocessed/val/15514.png
#   inflating: data_preprocessed/val/15515.png
#   inflating: data_preprocessed/val/15536.png
#   inflating: data_preprocessed/val/15543.png
#   inflating: data_preprocessed/val/15572.png
#   inflating: data_preprocessed/val/15579.png
#   inflating: data_preprocessed/val/15596.png
#   inflating: data_preprocessed/val/15610.png
#   inflating: data_preprocessed/val/15614.png
#   inflating: data_preprocessed/val/15618.png
#   inflating: data_preprocessed/val/15635.png
#   inflating: data_preprocessed/val/15641.png
#   inflating: data_preprocessed/val/15649.png
#   inflating: data_preprocessed/val/15657.png
#   inflating: data_preprocessed/val/15664.png
#   inflating: data_preprocessed/val/15678.png
#   inflating: data_preprocessed/val/15680.png
#   inflating: data_preprocessed/val/15683.png
#   inflating: data_preprocessed/val/15686.png
#   inflating: data_preprocessed/val/15694.png
#   inflating: data_preprocessed/val/15697.png
#   inflating: data_preprocessed/val/157.png
#   inflating: data_preprocessed/val/15709.png
#   inflating: data_preprocessed/val/15715.png
#   inflating: data_preprocessed/val/15717.png
#   inflating: data_preprocessed/val/15718.png
#   inflating: data_preprocessed/val/15725.png
#   inflating: data_preprocessed/val/15726.png
#   inflating: data_preprocessed/val/15740.png
#   inflating: data_preprocessed/val/15743.png
#   inflating: data_preprocessed/val/15752.png
#   inflating: data_preprocessed/val/15753.png
#   inflating: data_preprocessed/val/15761.png
#   inflating: data_preprocessed/val/15774.png
#   inflating: data_preprocessed/val/15775.png
#   inflating: data_preprocessed/val/15783.png
#   inflating: data_preprocessed/val/15787.png
#   inflating: data_preprocessed/val/15790.png
#   inflating: data_preprocessed/val/15794.png
#   inflating: data_preprocessed/val/15815.png
#   inflating: data_preprocessed/val/15829.png
#   inflating: data_preprocessed/val/15836.png
#   inflating: data_preprocessed/val/15838.png
#   inflating: data_preprocessed/val/15841.png
#   inflating: data_preprocessed/val/15846.png
#   inflating: data_preprocessed/val/15863.png
#   inflating: data_preprocessed/val/15866.png
#   inflating: data_preprocessed/val/15867.png
#   inflating: data_preprocessed/val/15869.png
#   inflating: data_preprocessed/val/15894.png
#   inflating: data_preprocessed/val/15902.png
#   inflating: data_preprocessed/val/15905.png
#   inflating: data_preprocessed/val/15908.png
#   inflating: data_preprocessed/val/15911.png
#   inflating: data_preprocessed/val/15916.png
#   inflating: data_preprocessed/val/1592.png
#   inflating: data_preprocessed/val/15923.png
#   inflating: data_preprocessed/val/15927.png
#   inflating: data_preprocessed/val/15942.png
#   inflating: data_preprocessed/val/15944.png
#   inflating: data_preprocessed/val/15946.png
#   inflating: data_preprocessed/val/15956.png
#   inflating: data_preprocessed/val/15963.png
#   inflating: data_preprocessed/val/15973.png
#   inflating: data_preprocessed/val/15974.png
#   inflating: data_preprocessed/val/15979.png
#   inflating: data_preprocessed/val/15993.png
#   inflating: data_preprocessed/val/1600.png
#   inflating: data_preprocessed/val/16006.png
#   inflating: data_preprocessed/val/16007.png
#   inflating: data_preprocessed/val/16010.png
#   inflating: data_preprocessed/val/16057.png
#   inflating: data_preprocessed/val/16061.png
#   inflating: data_preprocessed/val/16065.png
#   inflating: data_preprocessed/val/16078.png
#   inflating: data_preprocessed/val/16080.png
#   inflating: data_preprocessed/val/16087.png
#   inflating: data_preprocessed/val/16089.png
#   inflating: data_preprocessed/val/16096.png
#   inflating: data_preprocessed/val/161.png
#   inflating: data_preprocessed/val/16109.png
#   inflating: data_preprocessed/val/1611.png
#   inflating: data_preprocessed/val/1612.png
#   inflating: data_preprocessed/val/16120.png
#   inflating: data_preprocessed/val/16124.png
#   inflating: data_preprocessed/val/16127.png
#   inflating: data_preprocessed/val/16131.png
#   inflating: data_preprocessed/val/16147.png
#   inflating: data_preprocessed/val/16150.png
#   inflating: data_preprocessed/val/16151.png
#   inflating: data_preprocessed/val/16152.png
#   inflating: data_preprocessed/val/16161.png
#   inflating: data_preprocessed/val/16162.png
#   inflating: data_preprocessed/val/16164.png
#   inflating: data_preprocessed/val/16170.png
#   inflating: data_preprocessed/val/16177.png
#   inflating: data_preprocessed/val/16180.png
#   inflating: data_preprocessed/val/1620.png
#   inflating: data_preprocessed/val/16211.png
#   inflating: data_preprocessed/val/16213.png
#   inflating: data_preprocessed/val/16237.png
#   inflating: data_preprocessed/val/16240.png
#   inflating: data_preprocessed/val/16244.png
#   inflating: data_preprocessed/val/16247.png
#   inflating: data_preprocessed/val/16256.png
#   inflating: data_preprocessed/val/16289.png
#   inflating: data_preprocessed/val/16296.png
#   inflating: data_preprocessed/val/16309.png
#   inflating: data_preprocessed/val/16316.png
#   inflating: data_preprocessed/val/16321.png
#   inflating: data_preprocessed/val/16335.png
#   inflating: data_preprocessed/val/16337.png
#   inflating: data_preprocessed/val/1634.png
#   inflating: data_preprocessed/val/16346.png
#   inflating: data_preprocessed/val/16353.png
#   inflating: data_preprocessed/val/16355.png
#   inflating: data_preprocessed/val/16363.png
#   inflating: data_preprocessed/val/16365.png
#   inflating: data_preprocessed/val/164.png
#   inflating: data_preprocessed/val/16400.png
#   inflating: data_preprocessed/val/16407.png
#   inflating: data_preprocessed/val/1645.png
#   inflating: data_preprocessed/val/16450.png
#   inflating: data_preprocessed/val/16452.png
#   inflating: data_preprocessed/val/16463.png
#   inflating: data_preprocessed/val/16473.png
#   inflating: data_preprocessed/val/16474.png
#   inflating: data_preprocessed/val/16476.png
#   inflating: data_preprocessed/val/16480.png
#   inflating: data_preprocessed/val/16488.png
#   inflating: data_preprocessed/val/16494.png
#   inflating: data_preprocessed/val/16498.png
#   inflating: data_preprocessed/val/16511.png
#   inflating: data_preprocessed/val/16512.png
#   inflating: data_preprocessed/val/16514.png
#   inflating: data_preprocessed/val/16519.png
#   inflating: data_preprocessed/val/16525.png
#   inflating: data_preprocessed/val/16526.png
#   inflating: data_preprocessed/val/16534.png
#   inflating: data_preprocessed/val/16540.png
#   inflating: data_preprocessed/val/16541.png
#   inflating: data_preprocessed/val/16544.png
#   inflating: data_preprocessed/val/16560.png
#   inflating: data_preprocessed/val/16562.png
#   inflating: data_preprocessed/val/16564.png
#   inflating: data_preprocessed/val/16569.png
#   inflating: data_preprocessed/val/16579.png
#   inflating: data_preprocessed/val/16580.png
#   inflating: data_preprocessed/val/16589.png
#   inflating: data_preprocessed/val/16602.png
#   inflating: data_preprocessed/val/16605.png
#   inflating: data_preprocessed/val/16616.png
#   inflating: data_preprocessed/val/16621.png
#   inflating: data_preprocessed/val/16637.png
#   inflating: data_preprocessed/val/16647.png
#   inflating: data_preprocessed/val/16652.png
#   inflating: data_preprocessed/val/1666.png
#   inflating: data_preprocessed/val/16663.png
#   inflating: data_preprocessed/val/16665.png
#   inflating: data_preprocessed/val/16667.png
#   inflating: data_preprocessed/val/16670.png
#   inflating: data_preprocessed/val/16672.png
#   inflating: data_preprocessed/val/16678.png
#   inflating: data_preprocessed/val/16682.png
#   inflating: data_preprocessed/val/16693.png
#   inflating: data_preprocessed/val/16697.png
#   inflating: data_preprocessed/val/16702.png
#   inflating: data_preprocessed/val/16709.png
#   inflating: data_preprocessed/val/16712.png
#   inflating: data_preprocessed/val/16717.png
#   inflating: data_preprocessed/val/1672.png
#   inflating: data_preprocessed/val/16725.png
#   inflating: data_preprocessed/val/16730.png
#   inflating: data_preprocessed/val/16733.png
#   inflating: data_preprocessed/val/16760.png
#   inflating: data_preprocessed/val/16762.png
#   inflating: data_preprocessed/val/16763.png
#   inflating: data_preprocessed/val/1677.png
#   inflating: data_preprocessed/val/16772.png
#   inflating: data_preprocessed/val/16781.png
#   inflating: data_preprocessed/val/16782.png
#   inflating: data_preprocessed/val/16795.png
#   inflating: data_preprocessed/val/16796.png
#   inflating: data_preprocessed/val/16799.png
#   inflating: data_preprocessed/val/16813.png
#   inflating: data_preprocessed/val/16814.png
#   inflating: data_preprocessed/val/16816.png
#   inflating: data_preprocessed/val/16823.png
#   inflating: data_preprocessed/val/16827.png
#   inflating: data_preprocessed/val/16828.png
#   inflating: data_preprocessed/val/16839.png
#   inflating: data_preprocessed/val/16840.png
#   inflating: data_preprocessed/val/16851.png
#   inflating: data_preprocessed/val/16856.png
#   inflating: data_preprocessed/val/16857.png
#   inflating: data_preprocessed/val/16875.png
#   inflating: data_preprocessed/val/16883.png
#   inflating: data_preprocessed/val/16892.png
#   inflating: data_preprocessed/val/16896.png
#   inflating: data_preprocessed/val/169.png
#   inflating: data_preprocessed/val/16901.png
#   inflating: data_preprocessed/val/16905.png
#   inflating: data_preprocessed/val/16916.png
#   inflating: data_preprocessed/val/16920.png
#   inflating: data_preprocessed/val/16935.png
#   inflating: data_preprocessed/val/16939.png
#   inflating: data_preprocessed/val/16957.png
#   inflating: data_preprocessed/val/16958.png
#   inflating: data_preprocessed/val/1696.png
#   inflating: data_preprocessed/val/16965.png
#   inflating: data_preprocessed/val/16980.png
#   inflating: data_preprocessed/val/16989.png
#   inflating: data_preprocessed/val/16991.png
#   inflating: data_preprocessed/val/16992.png
#   inflating: data_preprocessed/val/17003.png
#   inflating: data_preprocessed/val/1701.png
#   inflating: data_preprocessed/val/17013.png
#   inflating: data_preprocessed/val/17014.png
#   inflating: data_preprocessed/val/17017.png
#   inflating: data_preprocessed/val/17019.png
#   inflating: data_preprocessed/val/17025.png
#   inflating: data_preprocessed/val/17026.png
#   inflating: data_preprocessed/val/17030.png
#   inflating: data_preprocessed/val/17038.png
#   inflating: data_preprocessed/val/17061.png
#   inflating: data_preprocessed/val/17063.png
#   inflating: data_preprocessed/val/17074.png
#   inflating: data_preprocessed/val/17087.png
#   inflating: data_preprocessed/val/17089.png
#   inflating: data_preprocessed/val/17091.png
#   inflating: data_preprocessed/val/17106.png
#   inflating: data_preprocessed/val/17138.png
#   inflating: data_preprocessed/val/17141.png
#   inflating: data_preprocessed/val/17149.png
#   inflating: data_preprocessed/val/17157.png
#   inflating: data_preprocessed/val/17166.png
#   inflating: data_preprocessed/val/17173.png
#   inflating: data_preprocessed/val/17182.png
#   inflating: data_preprocessed/val/17184.png
#   inflating: data_preprocessed/val/17199.png
#   inflating: data_preprocessed/val/1720.png
#   inflating: data_preprocessed/val/17211.png
#   inflating: data_preprocessed/val/17214.png
#   inflating: data_preprocessed/val/17219.png
#   inflating: data_preprocessed/val/17222.png
#   inflating: data_preprocessed/val/17229.png
#   inflating: data_preprocessed/val/17240.png
#   inflating: data_preprocessed/val/17248.png
#   inflating: data_preprocessed/val/17251.png
#   inflating: data_preprocessed/val/17268.png
#   inflating: data_preprocessed/val/17276.png
#   inflating: data_preprocessed/val/17289.png
#   inflating: data_preprocessed/val/17307.png
#   inflating: data_preprocessed/val/17309.png
#   inflating: data_preprocessed/val/17330.png
#   inflating: data_preprocessed/val/17332.png
#   inflating: data_preprocessed/val/1734.png
#   inflating: data_preprocessed/val/17348.png
#   inflating: data_preprocessed/val/17355.png
#   inflating: data_preprocessed/val/17368.png
#   inflating: data_preprocessed/val/17373.png
#   inflating: data_preprocessed/val/17374.png
#   inflating: data_preprocessed/val/17375.png
#   inflating: data_preprocessed/val/17381.png
#   inflating: data_preprocessed/val/17389.png
#   inflating: data_preprocessed/val/1739.png
#   inflating: data_preprocessed/val/17390.png
#   inflating: data_preprocessed/val/1742.png
#   inflating: data_preprocessed/val/17430.png
#   inflating: data_preprocessed/val/17444.png
#   inflating: data_preprocessed/val/17445.png
#   inflating: data_preprocessed/val/17449.png
#   inflating: data_preprocessed/val/17457.png
#   inflating: data_preprocessed/val/17461.png
#   inflating: data_preprocessed/val/17462.png
#   inflating: data_preprocessed/val/17504.png
#   inflating: data_preprocessed/val/17509.png
#   inflating: data_preprocessed/val/17516.png
#   inflating: data_preprocessed/val/17529.png
#   inflating: data_preprocessed/val/17532.png
#   inflating: data_preprocessed/val/17538.png
#   inflating: data_preprocessed/val/17539.png
#   inflating: data_preprocessed/val/17540.png
#   inflating: data_preprocessed/val/17544.png
#   inflating: data_preprocessed/val/17546.png
#   inflating: data_preprocessed/val/1757.png
#   inflating: data_preprocessed/val/17577.png
#   inflating: data_preprocessed/val/17582.png
#   inflating: data_preprocessed/val/17596.png
#   inflating: data_preprocessed/val/17600.png
#   inflating: data_preprocessed/val/17615.png
#   inflating: data_preprocessed/val/1762.png
#   inflating: data_preprocessed/val/17622.png
#   inflating: data_preprocessed/val/17628.png
#   inflating: data_preprocessed/val/17634.png
#   inflating: data_preprocessed/val/17637.png
#   inflating: data_preprocessed/val/17638.png
#   inflating: data_preprocessed/val/17647.png
#   inflating: data_preprocessed/val/17650.png
#   inflating: data_preprocessed/val/17658.png
#   inflating: data_preprocessed/val/17668.png
#   inflating: data_preprocessed/val/17672.png
#   inflating: data_preprocessed/val/17673.png
#   inflating: data_preprocessed/val/17682.png
#   inflating: data_preprocessed/val/17683.png
#   inflating: data_preprocessed/val/17694.png
#   inflating: data_preprocessed/val/17699.png
#   inflating: data_preprocessed/val/17704.png
#   inflating: data_preprocessed/val/17707.png
#   inflating: data_preprocessed/val/17712.png
#   inflating: data_preprocessed/val/17717.png
#   inflating: data_preprocessed/val/17720.png
#   inflating: data_preprocessed/val/17722.png
#   inflating: data_preprocessed/val/17726.png
#   inflating: data_preprocessed/val/17729.png
#   inflating: data_preprocessed/val/17733.png
#   inflating: data_preprocessed/val/17743.png
#   inflating: data_preprocessed/val/17748.png
#   inflating: data_preprocessed/val/1775.png
#   inflating: data_preprocessed/val/17750.png
#   inflating: data_preprocessed/val/17757.png
#   inflating: data_preprocessed/val/17759.png
#   inflating: data_preprocessed/val/17763.png
#   inflating: data_preprocessed/val/17772.png
#   inflating: data_preprocessed/val/17775.png
#   inflating: data_preprocessed/val/17779.png
#   inflating: data_preprocessed/val/17790.png
#   inflating: data_preprocessed/val/17792.png
#   inflating: data_preprocessed/val/1781.png
#   inflating: data_preprocessed/val/17810.png
#   inflating: data_preprocessed/val/17813.png
#   inflating: data_preprocessed/val/17818.png
#   inflating: data_preprocessed/val/17822.png
#   inflating: data_preprocessed/val/17829.png
#   inflating: data_preprocessed/val/1783.png
#   inflating: data_preprocessed/val/17837.png
#   inflating: data_preprocessed/val/1785.png
#   inflating: data_preprocessed/val/17851.png
#   inflating: data_preprocessed/val/17853.png
#   inflating: data_preprocessed/val/17866.png
#   inflating: data_preprocessed/val/17883.png
#   inflating: data_preprocessed/val/17899.png
#   inflating: data_preprocessed/val/17900.png
#   inflating: data_preprocessed/val/17906.png
#   inflating: data_preprocessed/val/17915.png
#   inflating: data_preprocessed/val/17926.png
#   inflating: data_preprocessed/val/17927.png
#   inflating: data_preprocessed/val/17950.png
#   inflating: data_preprocessed/val/17952.png
#   inflating: data_preprocessed/val/17957.png
#   inflating: data_preprocessed/val/17958.png
#   inflating: data_preprocessed/val/17961.png
#   inflating: data_preprocessed/val/17976.png
#   inflating: data_preprocessed/val/17978.png
#   inflating: data_preprocessed/val/17984.png
#   inflating: data_preprocessed/val/17988.png
#   inflating: data_preprocessed/val/17991.png
#   inflating: data_preprocessed/val/18023.png
#   inflating: data_preprocessed/val/18034.png
#   inflating: data_preprocessed/val/18041.png
#   inflating: data_preprocessed/val/18042.png
#   inflating: data_preprocessed/val/18049.png
#   inflating: data_preprocessed/val/18055.png
#   inflating: data_preprocessed/val/18058.png
#   inflating: data_preprocessed/val/18061.png
#   inflating: data_preprocessed/val/18067.png
#   inflating: data_preprocessed/val/18083.png
#   inflating: data_preprocessed/val/18096.png
#   inflating: data_preprocessed/val/1810.png
#   inflating: data_preprocessed/val/18100.png
#   inflating: data_preprocessed/val/18112.png
#   inflating: data_preprocessed/val/18118.png
#   inflating: data_preprocessed/val/18122.png
#   inflating: data_preprocessed/val/18129.png
#   inflating: data_preprocessed/val/1813.png
#   inflating: data_preprocessed/val/18145.png
#   inflating: data_preprocessed/val/18149.png
#   inflating: data_preprocessed/val/18168.png
#   inflating: data_preprocessed/val/18172.png
#   inflating: data_preprocessed/val/18179.png
#   inflating: data_preprocessed/val/18196.png
#   inflating: data_preprocessed/val/18216.png
#   inflating: data_preprocessed/val/18233.png
#   inflating: data_preprocessed/val/18238.png
#   inflating: data_preprocessed/val/1824.png
#   inflating: data_preprocessed/val/18240.png
#   inflating: data_preprocessed/val/18243.png
#   inflating: data_preprocessed/val/18249.png
#   inflating: data_preprocessed/val/18258.png
#   inflating: data_preprocessed/val/1826.png
#   inflating: data_preprocessed/val/18279.png
#   inflating: data_preprocessed/val/18280.png
#   inflating: data_preprocessed/val/18288.png
#   inflating: data_preprocessed/val/18300.png
#   inflating: data_preprocessed/val/18303.png
#   inflating: data_preprocessed/val/18326.png
#   inflating: data_preprocessed/val/18336.png
#   inflating: data_preprocessed/val/18345.png
#   inflating: data_preprocessed/val/18359.png
#   inflating: data_preprocessed/val/1836.png
#   inflating: data_preprocessed/val/18368.png
#   inflating: data_preprocessed/val/18384.png
#   inflating: data_preprocessed/val/18392.png
#   inflating: data_preprocessed/val/18394.png
#   inflating: data_preprocessed/val/18417.png
#   inflating: data_preprocessed/val/18419.png
#   inflating: data_preprocessed/val/18432.png
#   inflating: data_preprocessed/val/18447.png
#   inflating: data_preprocessed/val/18454.png
#   inflating: data_preprocessed/val/18456.png
#   inflating: data_preprocessed/val/18467.png
#   inflating: data_preprocessed/val/18475.png
#   inflating: data_preprocessed/val/18488.png
#   inflating: data_preprocessed/val/18493.png
#   inflating: data_preprocessed/val/18494.png
#   inflating: data_preprocessed/val/185.png
#   inflating: data_preprocessed/val/18504.png
#   inflating: data_preprocessed/val/18511.png
#   inflating: data_preprocessed/val/18515.png
#   inflating: data_preprocessed/val/18518.png
#   inflating: data_preprocessed/val/1852.png
#   inflating: data_preprocessed/val/18526.png
#   inflating: data_preprocessed/val/18544.png
#   inflating: data_preprocessed/val/18548.png
#   inflating: data_preprocessed/val/18549.png
#   inflating: data_preprocessed/val/18576.png
#   inflating: data_preprocessed/val/18582.png
#   inflating: data_preprocessed/val/18591.png
#   inflating: data_preprocessed/val/18595.png
#   inflating: data_preprocessed/val/18598.png
#   inflating: data_preprocessed/val/18599.png
#   inflating: data_preprocessed/val/18600.png
#   inflating: data_preprocessed/val/18604.png
#   inflating: data_preprocessed/val/18613.png
#   inflating: data_preprocessed/val/18627.png
#   inflating: data_preprocessed/val/18630.png
#   inflating: data_preprocessed/val/18638.png
#   inflating: data_preprocessed/val/18640.png
#   inflating: data_preprocessed/val/18642.png
#   inflating: data_preprocessed/val/1865.png
#   inflating: data_preprocessed/val/18657.png
#   inflating: data_preprocessed/val/1867.png
#   inflating: data_preprocessed/val/18672.png
#   inflating: data_preprocessed/val/18675.png
#   inflating: data_preprocessed/val/18681.png
#   inflating: data_preprocessed/val/18682.png
#   inflating: data_preprocessed/val/18707.png
#   inflating: data_preprocessed/val/18725.png
#   inflating: data_preprocessed/val/18736.png
#   inflating: data_preprocessed/val/18743.png
#   inflating: data_preprocessed/val/18750.png
#   inflating: data_preprocessed/val/18773.png
#   inflating: data_preprocessed/val/18774.png
#   inflating: data_preprocessed/val/18775.png
#   inflating: data_preprocessed/val/18782.png
#   inflating: data_preprocessed/val/1882.png
#   inflating: data_preprocessed/val/18824.png
#   inflating: data_preprocessed/val/18826.png
#   inflating: data_preprocessed/val/18829.png
#   inflating: data_preprocessed/val/18836.png
#   inflating: data_preprocessed/val/18839.png
#   inflating: data_preprocessed/val/18849.png
#   inflating: data_preprocessed/val/18855.png
#   inflating: data_preprocessed/val/18858.png
#   inflating: data_preprocessed/val/18863.png
#   inflating: data_preprocessed/val/18869.png
#   inflating: data_preprocessed/val/18873.png
#   inflating: data_preprocessed/val/18891.png
#   inflating: data_preprocessed/val/18899.png
#   inflating: data_preprocessed/val/18905.png
#   inflating: data_preprocessed/val/18906.png
#   inflating: data_preprocessed/val/18912.png
#   inflating: data_preprocessed/val/18925.png
#   inflating: data_preprocessed/val/18934.png
#   inflating: data_preprocessed/val/18943.png
#   inflating: data_preprocessed/val/18953.png
#   inflating: data_preprocessed/val/18957.png
#   inflating: data_preprocessed/val/1897.png
#   inflating: data_preprocessed/val/18973.png
#   inflating: data_preprocessed/val/18977.png
#   inflating: data_preprocessed/val/18988.png
#   inflating: data_preprocessed/val/18990.png
#   inflating: data_preprocessed/val/18991.png
#   inflating: data_preprocessed/val/18994.png
#   inflating: data_preprocessed/val/19006.png
#   inflating: data_preprocessed/val/19010.png
#   inflating: data_preprocessed/val/19027.png
#   inflating: data_preprocessed/val/19029.png
#   inflating: data_preprocessed/val/19039.png
#   inflating: data_preprocessed/val/19040.png
#   inflating: data_preprocessed/val/19043.png
#   inflating: data_preprocessed/val/19052.png
#   inflating: data_preprocessed/val/19054.png
#   inflating: data_preprocessed/val/19056.png
#   inflating: data_preprocessed/val/19063.png
#   inflating: data_preprocessed/val/19065.png
#   inflating: data_preprocessed/val/1909.png
#   inflating: data_preprocessed/val/19102.png
#   inflating: data_preprocessed/val/19106.png
#   inflating: data_preprocessed/val/19117.png
#   inflating: data_preprocessed/val/19122.png
#   inflating: data_preprocessed/val/19129.png
#   inflating: data_preprocessed/val/1913.png
#   inflating: data_preprocessed/val/19131.png
#   inflating: data_preprocessed/val/19135.png
#   inflating: data_preprocessed/val/1914.png
#   inflating: data_preprocessed/val/1915.png
#   inflating: data_preprocessed/val/19152.png
#   inflating: data_preprocessed/val/19156.png
#   inflating: data_preprocessed/val/19158.png
#   inflating: data_preprocessed/val/19167.png
#   inflating: data_preprocessed/val/19169.png
#   inflating: data_preprocessed/val/19192.png
#   inflating: data_preprocessed/val/19195.png
#   inflating: data_preprocessed/val/19206.png
#   inflating: data_preprocessed/val/19207.png
#   inflating: data_preprocessed/val/19209.png
#   inflating: data_preprocessed/val/19220.png
#   inflating: data_preprocessed/val/19225.png
#   inflating: data_preprocessed/val/19229.png
#   inflating: data_preprocessed/val/19240.png
#   inflating: data_preprocessed/val/19254.png
#   inflating: data_preprocessed/val/1926.png
#   inflating: data_preprocessed/val/19261.png
#   inflating: data_preprocessed/val/19262.png
#   inflating: data_preprocessed/val/19276.png
#   inflating: data_preprocessed/val/19284.png
#   inflating: data_preprocessed/val/19293.png
#   inflating: data_preprocessed/val/193.png
#   inflating: data_preprocessed/val/19310.png
#   inflating: data_preprocessed/val/19311.png
#   inflating: data_preprocessed/val/19312.png
#   inflating: data_preprocessed/val/19319.png
#   inflating: data_preprocessed/val/19325.png
#   inflating: data_preprocessed/val/19346.png
#   inflating: data_preprocessed/val/19360.png
#   inflating: data_preprocessed/val/19365.png
#   inflating: data_preprocessed/val/19374.png
#   inflating: data_preprocessed/val/19380.png
#   inflating: data_preprocessed/val/19382.png
#   inflating: data_preprocessed/val/19390.png
#   inflating: data_preprocessed/val/1940.png
#   inflating: data_preprocessed/val/19403.png
#   inflating: data_preprocessed/val/19404.png
#   inflating: data_preprocessed/val/19420.png
#   inflating: data_preprocessed/val/1943.png
#   inflating: data_preprocessed/val/19434.png
#   inflating: data_preprocessed/val/1944.png
#   inflating: data_preprocessed/val/19468.png
#   inflating: data_preprocessed/val/19479.png
#   inflating: data_preprocessed/val/19498.png
#   inflating: data_preprocessed/val/19499.png
#   inflating: data_preprocessed/val/19502.png
#   inflating: data_preprocessed/val/19503.png
#   inflating: data_preprocessed/val/19506.png
#   inflating: data_preprocessed/val/19531.png
#   inflating: data_preprocessed/val/19542.png
#   inflating: data_preprocessed/val/19551.png
#   inflating: data_preprocessed/val/19552.png
#   inflating: data_preprocessed/val/19555.png
#   inflating: data_preprocessed/val/19557.png
#   inflating: data_preprocessed/val/19572.png
#   inflating: data_preprocessed/val/19578.png
#   inflating: data_preprocessed/val/19585.png
#   inflating: data_preprocessed/val/19598.png
#   inflating: data_preprocessed/val/19599.png
#   inflating: data_preprocessed/val/19602.png
#   inflating: data_preprocessed/val/19605.png
#   inflating: data_preprocessed/val/19608.png
#   inflating: data_preprocessed/val/19613.png
#   inflating: data_preprocessed/val/19630.png
#   inflating: data_preprocessed/val/19631.png
#   inflating: data_preprocessed/val/19632.png
#   inflating: data_preprocessed/val/19637.png
#   inflating: data_preprocessed/val/19639.png
#   inflating: data_preprocessed/val/19648.png
#   inflating: data_preprocessed/val/19656.png
#   inflating: data_preprocessed/val/19662.png
#   inflating: data_preprocessed/val/19664.png
#   inflating: data_preprocessed/val/19665.png
#   inflating: data_preprocessed/val/19673.png
#   inflating: data_preprocessed/val/19674.png
#   inflating: data_preprocessed/val/19687.png
#   inflating: data_preprocessed/val/19691.png
#   inflating: data_preprocessed/val/19708.png
#   inflating: data_preprocessed/val/19710.png
#   inflating: data_preprocessed/val/19716.png
#   inflating: data_preprocessed/val/19725.png
#   inflating: data_preprocessed/val/1973.png
#   inflating: data_preprocessed/val/19735.png
#   inflating: data_preprocessed/val/19741.png
#   inflating: data_preprocessed/val/19752.png
#   inflating: data_preprocessed/val/19755.png
#   inflating: data_preprocessed/val/1976.png
#   inflating: data_preprocessed/val/19762.png
#   inflating: data_preprocessed/val/19771.png
#   inflating: data_preprocessed/val/19775.png
#   inflating: data_preprocessed/val/19799.png
#   inflating: data_preprocessed/val/19801.png
#   inflating: data_preprocessed/val/19806.png
#   inflating: data_preprocessed/val/19810.png
#   inflating: data_preprocessed/val/19811.png
#   inflating: data_preprocessed/val/19812.png
#   inflating: data_preprocessed/val/19821.png
#   inflating: data_preprocessed/val/19823.png
#   inflating: data_preprocessed/val/19831.png
#   inflating: data_preprocessed/val/19846.png
#   inflating: data_preprocessed/val/19847.png
#   inflating: data_preprocessed/val/19858.png
#   inflating: data_preprocessed/val/19865.png
#   inflating: data_preprocessed/val/1987.png
#   inflating: data_preprocessed/val/19870.png
#   inflating: data_preprocessed/val/19875.png
#   inflating: data_preprocessed/val/19877.png
#   inflating: data_preprocessed/val/19879.png
#   inflating: data_preprocessed/val/19888.png
#   inflating: data_preprocessed/val/19894.png
#   inflating: data_preprocessed/val/199.png
#   inflating: data_preprocessed/val/19905.png
#   inflating: data_preprocessed/val/19928.png
#   inflating: data_preprocessed/val/19930.png
#   inflating: data_preprocessed/val/19935.png
#   inflating: data_preprocessed/val/19940.png
#   inflating: data_preprocessed/val/19944.png
#   inflating: data_preprocessed/val/19955.png
#   inflating: data_preprocessed/val/19961.png
#   inflating: data_preprocessed/val/19973.png
#   inflating: data_preprocessed/val/19976.png
#   inflating: data_preprocessed/val/19978.png
#   inflating: data_preprocessed/val/19981.png
#   inflating: data_preprocessed/val/19986.png
#   inflating: data_preprocessed/val/19988.png
#   inflating: data_preprocessed/val/20000.png
#   inflating: data_preprocessed/val/2001.png
#   inflating: data_preprocessed/val/20023.png
#   inflating: data_preprocessed/val/20040.png
#   inflating: data_preprocessed/val/20043.png
#   inflating: data_preprocessed/val/20069.png
#   inflating: data_preprocessed/val/20073.png
#   inflating: data_preprocessed/val/20078.png
#   inflating: data_preprocessed/val/2008.png
#   inflating: data_preprocessed/val/20087.png
#   inflating: data_preprocessed/val/20092.png
#   inflating: data_preprocessed/val/20100.png
#   inflating: data_preprocessed/val/20107.png
#   inflating: data_preprocessed/val/20109.png
#   inflating: data_preprocessed/val/20112.png
#   inflating: data_preprocessed/val/20118.png
#   inflating: data_preprocessed/val/20122.png
#   inflating: data_preprocessed/val/2014.png
#   inflating: data_preprocessed/val/20142.png
#   inflating: data_preprocessed/val/20144.png
#   inflating: data_preprocessed/val/20181.png
#   inflating: data_preprocessed/val/20186.png
#   inflating: data_preprocessed/val/20190.png
#   inflating: data_preprocessed/val/202.png
#   inflating: data_preprocessed/val/20201.png
#   inflating: data_preprocessed/val/20227.png
#   inflating: data_preprocessed/val/20231.png
#   inflating: data_preprocessed/val/20234.png
#   inflating: data_preprocessed/val/20244.png
#   inflating: data_preprocessed/val/20249.png
#   inflating: data_preprocessed/val/20261.png
#   inflating: data_preprocessed/val/20274.png
#   inflating: data_preprocessed/val/20277.png
#   inflating: data_preprocessed/val/20278.png
#   inflating: data_preprocessed/val/20280.png
#   inflating: data_preprocessed/val/20281.png
#   inflating: data_preprocessed/val/20287.png
#   inflating: data_preprocessed/val/20288.png
#   inflating: data_preprocessed/val/20292.png
#   inflating: data_preprocessed/val/20293.png
#   inflating: data_preprocessed/val/20295.png
#   inflating: data_preprocessed/val/20327.png
#   inflating: data_preprocessed/val/20345.png
#   inflating: data_preprocessed/val/20346.png
#   inflating: data_preprocessed/val/20355.png
#   inflating: data_preprocessed/val/20356.png
#   inflating: data_preprocessed/val/20359.png
#   inflating: data_preprocessed/val/20370.png
#   inflating: data_preprocessed/val/20377.png
#   inflating: data_preprocessed/val/20378.png
#   inflating: data_preprocessed/val/20380.png
#   inflating: data_preprocessed/val/20387.png
#   inflating: data_preprocessed/val/20414.png
#   inflating: data_preprocessed/val/2042.png
#   inflating: data_preprocessed/val/20420.png
#   inflating: data_preprocessed/val/20422.png
#   inflating: data_preprocessed/val/20424.png
#   inflating: data_preprocessed/val/20433.png
#   inflating: data_preprocessed/val/20453.png
#   inflating: data_preprocessed/val/2046.png
#   inflating: data_preprocessed/val/20467.png
#   inflating: data_preprocessed/val/2047.png
#   inflating: data_preprocessed/val/20474.png
#   inflating: data_preprocessed/val/20479.png
#   inflating: data_preprocessed/val/20488.png
#   inflating: data_preprocessed/val/2049.png
#   inflating: data_preprocessed/val/20496.png
#   inflating: data_preprocessed/val/205.png
#   inflating: data_preprocessed/val/20514.png
#   inflating: data_preprocessed/val/20522.png
#   inflating: data_preprocessed/val/20525.png
#   inflating: data_preprocessed/val/20536.png
#   inflating: data_preprocessed/val/20538.png
#   inflating: data_preprocessed/val/20543.png
#   inflating: data_preprocessed/val/20552.png
#   inflating: data_preprocessed/val/20555.png
#   inflating: data_preprocessed/val/20562.png
#   inflating: data_preprocessed/val/20564.png
#   inflating: data_preprocessed/val/20569.png
#   inflating: data_preprocessed/val/20571.png
#   inflating: data_preprocessed/val/20578.png
#   inflating: data_preprocessed/val/20580.png
#   inflating: data_preprocessed/val/20584.png
#   inflating: data_preprocessed/val/20588.png
#   inflating: data_preprocessed/val/20605.png
#   inflating: data_preprocessed/val/20608.png
#   inflating: data_preprocessed/val/20609.png
#   inflating: data_preprocessed/val/20618.png
#   inflating: data_preprocessed/val/20622.png
#   inflating: data_preprocessed/val/20623.png
#   inflating: data_preprocessed/val/20627.png
#   inflating: data_preprocessed/val/2063.png
#   inflating: data_preprocessed/val/20634.png
#   inflating: data_preprocessed/val/20637.png
#   inflating: data_preprocessed/val/20640.png
#   inflating: data_preprocessed/val/20657.png
#   inflating: data_preprocessed/val/20658.png
#   inflating: data_preprocessed/val/20667.png
#   inflating: data_preprocessed/val/20673.png
#   inflating: data_preprocessed/val/20678.png
#   inflating: data_preprocessed/val/2068.png
#   inflating: data_preprocessed/val/20682.png
#   inflating: data_preprocessed/val/20684.png
#   inflating: data_preprocessed/val/20690.png
#   inflating: data_preprocessed/val/20696.png
#   inflating: data_preprocessed/val/20706.png
#   inflating: data_preprocessed/val/2071.png
#   inflating: data_preprocessed/val/20715.png
#   inflating: data_preprocessed/val/20719.png
#   inflating: data_preprocessed/val/20723.png
#   inflating: data_preprocessed/val/20727.png
#   inflating: data_preprocessed/val/2073.png
#   inflating: data_preprocessed/val/20737.png
#   inflating: data_preprocessed/val/2074.png
#   inflating: data_preprocessed/val/20744.png
#   inflating: data_preprocessed/val/20746.png
#   inflating: data_preprocessed/val/20754.png
#   inflating: data_preprocessed/val/20756.png
# ...
#   inflating: data_preprocessed/val/7570.png
#   inflating: data_preprocessed/val/7572.png
#   inflating: data_preprocessed/val/7583.png
#   inflating: data_preprocessed/val/7591.png
#   inflating: data_preprocessed/val/7593.png
#   inflating: data_preprocessed/val/7601.png
#   inflating: data_preprocessed/val/7605.png
#   inflating: data_preprocessed/val/7608.png
#   inflating: data_preprocessed/val/7618.png
#   inflating: data_preprocessed/val/7626.png
#   inflating: data_preprocessed/val/7632.png
#   inflating: data_preprocessed/val/7634.png
#   inflating: data_preprocessed/val/7635.png
#   inflating: data_preprocessed/val/764.png
#   inflating: data_preprocessed/val/7645.png
#   inflating: data_preprocessed/val/7647.png
#   inflating: data_preprocessed/val/7649.png
#   inflating: data_preprocessed/val/7651.png
#   inflating: data_preprocessed/val/7663.png
#   inflating: data_preprocessed/val/7682.png
#   inflating: data_preprocessed/val/7692.png
#   inflating: data_preprocessed/val/7700.png
#   inflating: data_preprocessed/val/7701.png
#   inflating: data_preprocessed/val/7703.png
#   inflating: data_preprocessed/val/7708.png
#   inflating: data_preprocessed/val/7709.png
#   inflating: data_preprocessed/val/771.png
#   inflating: data_preprocessed/val/7716.png
#   inflating: data_preprocessed/val/7730.png
#   inflating: data_preprocessed/val/7753.png
#   inflating: data_preprocessed/val/7764.png
#   inflating: data_preprocessed/val/7793.png
#   inflating: data_preprocessed/val/7798.png
#   inflating: data_preprocessed/val/780.png
#   inflating: data_preprocessed/val/7804.png
#   inflating: data_preprocessed/val/7805.png
#   inflating: data_preprocessed/val/7812.png
#   inflating: data_preprocessed/val/7813.png
#   inflating: data_preprocessed/val/7824.png
#   inflating: data_preprocessed/val/7825.png
#   inflating: data_preprocessed/val/787.png
#   inflating: data_preprocessed/val/7898.png
#   inflating: data_preprocessed/val/790.png
#   inflating: data_preprocessed/val/7902.png
#   inflating: data_preprocessed/val/7907.png
#   inflating: data_preprocessed/val/7916.png
#   inflating: data_preprocessed/val/7919.png
#   inflating: data_preprocessed/val/7936.png
#   inflating: data_preprocessed/val/796.png
#   inflating: data_preprocessed/val/7961.png
#   inflating: data_preprocessed/val/7962.png
#   inflating: data_preprocessed/val/7963.png
#   inflating: data_preprocessed/val/7970.png
#   inflating: data_preprocessed/val/7974.png
#   inflating: data_preprocessed/val/798.png
#   inflating: data_preprocessed/val/7994.png
#   inflating: data_preprocessed/val/8013.png
#   inflating: data_preprocessed/val/8014.png
#   inflating: data_preprocessed/val/8015.png
#   inflating: data_preprocessed/val/8025.png
#   inflating: data_preprocessed/val/8029.png
#   inflating: data_preprocessed/val/8039.png
#   inflating: data_preprocessed/val/804.png
#   inflating: data_preprocessed/val/8041.png
#   inflating: data_preprocessed/val/8044.png
#   inflating: data_preprocessed/val/8046.png
#   inflating: data_preprocessed/val/8053.png
#   inflating: data_preprocessed/val/8062.png
#   inflating: data_preprocessed/val/810.png
#   inflating: data_preprocessed/val/8105.png
#   inflating: data_preprocessed/val/8107.png
#   inflating: data_preprocessed/val/8109.png
#   inflating: data_preprocessed/val/8112.png
#   inflating: data_preprocessed/val/8130.png
#   inflating: data_preprocessed/val/8136.png
#   inflating: data_preprocessed/val/8137.png
#   inflating: data_preprocessed/val/8141.png
#   inflating: data_preprocessed/val/8142.png
#   inflating: data_preprocessed/val/8151.png
#   inflating: data_preprocessed/val/8162.png
#   inflating: data_preprocessed/val/8167.png
#   inflating: data_preprocessed/val/8168.png
#   inflating: data_preprocessed/val/8174.png
#   inflating: data_preprocessed/val/818.png
#   inflating: data_preprocessed/val/8180.png
#   inflating: data_preprocessed/val/8198.png
#   inflating: data_preprocessed/val/8205.png
#   inflating: data_preprocessed/val/8221.png
#   inflating: data_preprocessed/val/8229.png
#   inflating: data_preprocessed/val/8233.png
#   inflating: data_preprocessed/val/8245.png
#   inflating: data_preprocessed/val/8250.png
#   inflating: data_preprocessed/val/8259.png
#   inflating: data_preprocessed/val/827.png
#   inflating: data_preprocessed/val/8276.png
#   inflating: data_preprocessed/val/8303.png
#   inflating: data_preprocessed/val/8308.png
#   inflating: data_preprocessed/val/8318.png
#   inflating: data_preprocessed/val/8323.png
#   inflating: data_preprocessed/val/8324.png
#   inflating: data_preprocessed/val/8329.png
#   inflating: data_preprocessed/val/833.png
#   inflating: data_preprocessed/val/8331.png
#   inflating: data_preprocessed/val/8340.png
#   inflating: data_preprocessed/val/8345.png
#   inflating: data_preprocessed/val/8346.png
#   inflating: data_preprocessed/val/8357.png
#   inflating: data_preprocessed/val/8380.png
#   inflating: data_preprocessed/val/8381.png
#   inflating: data_preprocessed/val/8401.png
#   inflating: data_preprocessed/val/8406.png
#   inflating: data_preprocessed/val/8412.png
#   inflating: data_preprocessed/val/8415.png
#   inflating: data_preprocessed/val/8420.png
#   inflating: data_preprocessed/val/8427.png
#   inflating: data_preprocessed/val/844.png
#   inflating: data_preprocessed/val/8441.png
#   inflating: data_preprocessed/val/8448.png
#   inflating: data_preprocessed/val/8453.png
#   inflating: data_preprocessed/val/8478.png
#   inflating: data_preprocessed/val/8481.png
#   inflating: data_preprocessed/val/8491.png
#   inflating: data_preprocessed/val/85.png
#   inflating: data_preprocessed/val/8525.png
#   inflating: data_preprocessed/val/8542.png
#   inflating: data_preprocessed/val/8548.png
#   inflating: data_preprocessed/val/8551.png
#   inflating: data_preprocessed/val/856.png
#   inflating: data_preprocessed/val/8562.png
#   inflating: data_preprocessed/val/8565.png
#   inflating: data_preprocessed/val/8581.png
#   inflating: data_preprocessed/val/859.png
#   inflating: data_preprocessed/val/8590.png
#   inflating: data_preprocessed/val/8618.png
#   inflating: data_preprocessed/val/8628.png
#   inflating: data_preprocessed/val/8632.png
#   inflating: data_preprocessed/val/8634.png
#   inflating: data_preprocessed/val/8644.png
#   inflating: data_preprocessed/val/8651.png
#   inflating: data_preprocessed/val/8652.png
#   inflating: data_preprocessed/val/867.png
#   inflating: data_preprocessed/val/8679.png
#   inflating: data_preprocessed/val/8685.png
#   inflating: data_preprocessed/val/8699.png
#   inflating: data_preprocessed/val/8717.png
#   inflating: data_preprocessed/val/8719.png
#   inflating: data_preprocessed/val/872.png
#   inflating: data_preprocessed/val/8730.png
#   inflating: data_preprocessed/val/8737.png
#   inflating: data_preprocessed/val/8749.png
#   inflating: data_preprocessed/val/8751.png
#   inflating: data_preprocessed/val/8753.png
#   inflating: data_preprocessed/val/8759.png
#   inflating: data_preprocessed/val/8767.png
#   inflating: data_preprocessed/val/8771.png
#   inflating: data_preprocessed/val/8772.png
#   inflating: data_preprocessed/val/8782.png
#   inflating: data_preprocessed/val/8785.png
#   inflating: data_preprocessed/val/8798.png
#   inflating: data_preprocessed/val/88.png
#   inflating: data_preprocessed/val/8821.png
#   inflating: data_preprocessed/val/8827.png
#   inflating: data_preprocessed/val/8838.png
#   inflating: data_preprocessed/val/885.png
#   inflating: data_preprocessed/val/8854.png
#   inflating: data_preprocessed/val/8857.png
#   inflating: data_preprocessed/val/886.png
#   inflating: data_preprocessed/val/8864.png
#   inflating: data_preprocessed/val/8871.png
#   inflating: data_preprocessed/val/8873.png
#   inflating: data_preprocessed/val/8886.png
#   inflating: data_preprocessed/val/891.png
#   inflating: data_preprocessed/val/8916.png
#   inflating: data_preprocessed/val/8918.png
#   inflating: data_preprocessed/val/8919.png
#   inflating: data_preprocessed/val/8923.png
#   inflating: data_preprocessed/val/8927.png
#   inflating: data_preprocessed/val/8928.png
#   inflating: data_preprocessed/val/8943.png
#   inflating: data_preprocessed/val/8949.png
#   inflating: data_preprocessed/val/8953.png
#   inflating: data_preprocessed/val/8954.png
#   inflating: data_preprocessed/val/8958.png
#   inflating: data_preprocessed/val/8963.png
#   inflating: data_preprocessed/val/897.png
#   inflating: data_preprocessed/val/8971.png
#   inflating: data_preprocessed/val/8972.png
#   inflating: data_preprocessed/val/8973.png
#   inflating: data_preprocessed/val/8974.png
#   inflating: data_preprocessed/val/8975.png
#   inflating: data_preprocessed/val/8980.png
#   inflating: data_preprocessed/val/8987.png
#   inflating: data_preprocessed/val/8997.png
#   inflating: data_preprocessed/val/90.png
#   inflating: data_preprocessed/val/9002.png
#   inflating: data_preprocessed/val/9012.png
#   inflating: data_preprocessed/val/9025.png
#   inflating: data_preprocessed/val/9028.png
#   inflating: data_preprocessed/val/9032.png
#   inflating: data_preprocessed/val/9033.png
#   inflating: data_preprocessed/val/9039.png
#   inflating: data_preprocessed/val/9041.png
#   inflating: data_preprocessed/val/9075.png
#   inflating: data_preprocessed/val/9076.png
#   inflating: data_preprocessed/val/9081.png
#   inflating: data_preprocessed/val/9109.png
#   inflating: data_preprocessed/val/9118.png
#   inflating: data_preprocessed/val/912.png
#   inflating: data_preprocessed/val/9127.png
#   inflating: data_preprocessed/val/9129.png
#   inflating: data_preprocessed/val/9133.png
#   inflating: data_preprocessed/val/9143.png
#   inflating: data_preprocessed/val/9145.png
#   inflating: data_preprocessed/val/9147.png
#   inflating: data_preprocessed/val/915.png
#   inflating: data_preprocessed/val/9154.png
#   inflating: data_preprocessed/val/9156.png
#   inflating: data_preprocessed/val/9166.png
#   inflating: data_preprocessed/val/9167.png
#   inflating: data_preprocessed/val/9173.png
#   inflating: data_preprocessed/val/9175.png
#   inflating: data_preprocessed/val/9177.png
#   inflating: data_preprocessed/val/9180.png
#   inflating: data_preprocessed/val/9188.png
#   inflating: data_preprocessed/val/9193.png
#   inflating: data_preprocessed/val/9197.png
#   inflating: data_preprocessed/val/9198.png
#   inflating: data_preprocessed/val/92.png
#   inflating: data_preprocessed/val/920.png
#   inflating: data_preprocessed/val/9202.png
#   inflating: data_preprocessed/val/9209.png
#   inflating: data_preprocessed/val/9226.png
#   inflating: data_preprocessed/val/9227.png
#   inflating: data_preprocessed/val/9245.png
#   inflating: data_preprocessed/val/9250.png
#   inflating: data_preprocessed/val/9253.png
#   inflating: data_preprocessed/val/9259.png
#   inflating: data_preprocessed/val/9265.png
#   inflating: data_preprocessed/val/9281.png
#   inflating: data_preprocessed/val/9287.png
#   inflating: data_preprocessed/val/9290.png
#   inflating: data_preprocessed/val/9292.png
#   inflating: data_preprocessed/val/9298.png
#   inflating: data_preprocessed/val/93.png
#   inflating: data_preprocessed/val/9305.png
#   inflating: data_preprocessed/val/931.png
#   inflating: data_preprocessed/val/9314.png
#   inflating: data_preprocessed/val/9318.png
#   inflating: data_preprocessed/val/9319.png
#   inflating: data_preprocessed/val/9342.png
#   inflating: data_preprocessed/val/9344.png
#   inflating: data_preprocessed/val/9356.png
#   inflating: data_preprocessed/val/9359.png
#   inflating: data_preprocessed/val/9360.png
#   inflating: data_preprocessed/val/9366.png
#   inflating: data_preprocessed/val/9412.png
#   inflating: data_preprocessed/val/9417.png
#   inflating: data_preprocessed/val/942.png
#   inflating: data_preprocessed/val/9424.png
#   inflating: data_preprocessed/val/944.png
#   inflating: data_preprocessed/val/9443.png
#   inflating: data_preprocessed/val/9471.png
#   inflating: data_preprocessed/val/9497.png
#   inflating: data_preprocessed/val/9500.png
#   inflating: data_preprocessed/val/9501.png
#   inflating: data_preprocessed/val/9508.png
#   inflating: data_preprocessed/val/951.png
#   inflating: data_preprocessed/val/9510.png
#   inflating: data_preprocessed/val/9514.png
#   inflating: data_preprocessed/val/9524.png
#   inflating: data_preprocessed/val/9534.png
#   inflating: data_preprocessed/val/955.png
#   inflating: data_preprocessed/val/9553.png
#   inflating: data_preprocessed/val/9569.png
#   inflating: data_preprocessed/val/957.png
#   inflating: data_preprocessed/val/9572.png
#   inflating: data_preprocessed/val/9580.png
#   inflating: data_preprocessed/val/9583.png
#   inflating: data_preprocessed/val/9596.png
#   inflating: data_preprocessed/val/9604.png
#   inflating: data_preprocessed/val/9609.png
#   inflating: data_preprocessed/val/9616.png
#   inflating: data_preprocessed/val/9620.png
#   inflating: data_preprocessed/val/9623.png
#   inflating: data_preprocessed/val/9628.png
#   inflating: data_preprocessed/val/9631.png
#   inflating: data_preprocessed/val/9637.png
#   inflating: data_preprocessed/val/9642.png
#   inflating: data_preprocessed/val/9655.png
#   inflating: data_preprocessed/val/9665.png
#   inflating: data_preprocessed/val/968.png
#   inflating: data_preprocessed/val/9689.png
#   inflating: data_preprocessed/val/969.png
#   inflating: data_preprocessed/val/9691.png
#   inflating: data_preprocessed/val/97.png
#   inflating: data_preprocessed/val/970.png
#   inflating: data_preprocessed/val/9709.png
#   inflating: data_preprocessed/val/9710.png
#   inflating: data_preprocessed/val/9713.png
#   inflating: data_preprocessed/val/9718.png
#   inflating: data_preprocessed/val/9723.png
#   inflating: data_preprocessed/val/9729.png
#   inflating: data_preprocessed/val/9734.png
#   inflating: data_preprocessed/val/9749.png
#   inflating: data_preprocessed/val/9756.png
#   inflating: data_preprocessed/val/976.png
#   inflating: data_preprocessed/val/977.png
#   inflating: data_preprocessed/val/9774.png
#   inflating: data_preprocessed/val/9784.png
#   inflating: data_preprocessed/val/9791.png
#   inflating: data_preprocessed/val/9794.png
#   inflating: data_preprocessed/val/9795.png
#   inflating: data_preprocessed/val/9796.png
#   inflating: data_preprocessed/val/980.png
#   inflating: data_preprocessed/val/9800.png
#   inflating: data_preprocessed/val/9814.png
#   inflating: data_preprocessed/val/9821.png
#   inflating: data_preprocessed/val/9822.png
#   inflating: data_preprocessed/val/983.png
#   inflating: data_preprocessed/val/9835.png
#   inflating: data_preprocessed/val/9837.png
#   inflating: data_preprocessed/val/984.png
#   inflating: data_preprocessed/val/9849.png
#   inflating: data_preprocessed/val/9859.png
#   inflating: data_preprocessed/val/9860.png
#   inflating: data_preprocessed/val/9863.png
#   inflating: data_preprocessed/val/9866.png
#   inflating: data_preprocessed/val/9871.png
#   inflating: data_preprocessed/val/9876.png
#   inflating: data_preprocessed/val/9890.png
#   inflating: data_preprocessed/val/990.png
#   inflating: data_preprocessed/val/9907.png
#   inflating: data_preprocessed/val/9909.png
#   inflating: data_preprocessed/val/9912.png
#   inflating: data_preprocessed/val/992.png
#   inflating: data_preprocessed/val/9928.png
#   inflating: data_preprocessed/val/993.png
#   inflating: data_preprocessed/val/9948.png
#   inflating: data_preprocessed/val/9951.png
#   inflating: data_preprocessed/val/9956.png
#   inflating: data_preprocessed/val/9963.png
#   inflating: data_preprocessed/val/9978.png
#   inflating: data_preprocessed/val/9979.png
#   inflating: data_preprocessed/val/9980.png
#   inflating: data_preprocessed/val/9982.png
#   inflating: data_preprocessed/val/9987.png
#   inflating: data_preprocessed/val/9992.png
#   inflating: data_preprocessed/val/9996.png
#   inflating: data_preprocessed/val.csv

# %%
import tensorflow as tf
from tensorflow.keras import applications, layers, models, callbacks
import cv2
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from typing import Tuple, Optional

# 1. Custom Metrics
class HourMAE(tf.keras.metrics.Metric):
    def __init__(self, name='hour_mae', **kwargs):
        super().__init__(name=name, **kwargs)
        self.mae = tf.keras.metrics.MeanAbsoluteError()

    def update_state(self, y_true, y_pred, sample_weight=None):
        true_h = y_true[..., 0] * 12
        pred_h = y_pred[..., 0] * 12
        self.mae.update_state(true_h, pred_h)

    def result(self):
        return self.mae.result()

    def reset_state(self):
        self.mae.reset_state()

class MinuteMAE(tf.keras.metrics.Metric):
    def __init__(self, name='minute_mae', **kwargs):
        super().__init__(name=name, **kwargs)
        self.mae = tf.keras.metrics.MeanAbsoluteError()

    def update_state(self, y_true, y_pred, sample_weight=None):
        true_m = y_true[..., 1] * 60
        pred_m = y_pred[..., 1] * 60
        self.mae.update_state(true_m, pred_m)

    def result(self):
        return self.mae.result()

    def reset_state(self):
        self.mae.reset_state()

class SecondMAE(tf.keras.metrics.Metric):
    def __init__(self, name='second_mae', **kwargs):
        super().__init__(name=name, **kwargs)
        self.mae = tf.keras.metrics.MeanAbsoluteError()

    def update_state(self, y_true, y_pred, sample_weight=None):
        true_s = y_true[..., 2] * 60
        pred_s = y_pred[..., 2] * 60
        self.mae.update_state(true_s, pred_s)

    def result(self):
        return self.mae.result()

    def reset_state(self):
        self.mae.reset_state()

# 2. Model Architecture
def create_time_model(img_size=(224, 224), base_model_name='resnet50'):
    if base_model_name == 'resnet50':
        base_model = applications.ResNet50(
            weights='imagenet',
            include_top=False,
            input_shape=(*img_size, 3))
    else:
        base_model = applications.VGG16(
            weights='imagenet',
            include_top=False,
            input_shape=(*img_size, 3))

    base_model.trainable = False

    inputs = layers.Input(shape=(*img_size, 3))
    x = base_model(inputs)
    x = layers.GlobalAveragePooling2D()(x)
    x = layers.Dense(256, activation='relu')(x)
    x = layers.Dropout(0.3)(x)
    outputs = layers.Dense(3, activation='linear')(x)  # [hour, minute, second]

    return models.Model(inputs, outputs)

# 3. Data Generator
class CustomDataGenerator(tf.keras.utils.Sequence):
    def __init__(self, df, batch_size=32, img_size=(224, 224), shuffle=True):
        self.df = df
        self.batch_size = batch_size
        self.img_size = img_size
        self.shuffle = shuffle
        self.n = len(df)
        self.indices = np.arange(self.n)

        # Clean paths and normalize labels
        self.image_paths = df['new_img_dir'].str.replace('artifacts/', '/content/artifacts/').str.replace('\\', '/')
        self.labels = df[['hour', 'minute', 'second']].values / [12, 60, 60]

        self.on_epoch_end()

    def __len__(self):
        return int(np.ceil(self.n / self.batch_size))

    def __getitem__(self, index):
        batch_indices = self.indices[index*self.batch_size:(index+1)*self.batch_size]

        X = np.empty((len(batch_indices), *self.img_size, 3), dtype=np.float32)
        y = np.empty((len(batch_indices), 3), dtype=np.float32)

        for i, idx in enumerate(batch_indices):
            X[i] = self._load_image(self.image_paths[idx])
            y[i] = self.labels[idx]

        return X, y

    def _load_image(self, path: str) -> np.ndarray:
        try:
            img = cv2.imread(path, cv2.IMREAD_COLOR)
            img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
            img = cv2.resize(img, self.img_size)
            return img.astype(np.float32) / 255.0
        except:
            return np.zeros((*self.img_size, 3), dtype=np.float32)

    def on_epoch_end(self):
        if self.shuffle:
            np.random.shuffle(self.indices)

# 4. Training Components
def cyclic_time_loss(y_true, y_pred):
    true_time = y_true * [2*np.pi/12, 2*np.pi/60, 2*np.pi/60]
    pred_time = y_pred * [2*np.pi/12, 2*np.pi/60, 2*np.pi/60]
    return tf.reduce_mean(tf.abs(tf.sin((true_time - pred_time)/2)))

def train_model(train_gen, val_gen, img_size=(224, 224)):
    model = create_time_model(img_size)

    model.compile(
        optimizer=tf.keras.optimizers.Adam(1e-3),
        loss=cyclic_time_loss,
        metrics=[HourMAE(), MinuteMAE(), SecondMAE()]
    )

    callbacks_lst = [
        tf.keras.callbacks.EarlyStopping(
            patience=15,
            monitor='val_hour_mae',
            mode='min',
            restore_best_weights=True
        ),
        tf.keras.callbacks.ModelCheckpoint(
            'best_clock_model.h5',
            monitor='val_hour_mae',
            save_best_only=True,
            mode='min',
            verbose=1
        ),
        tf.keras.callbacks.ReduceLROnPlateau(
            monitor='val_hour_mae',
            factor=0.2,
            patience=5,
            mode='min',
            min_lr=1e-6
        )
    ]

    history = model.fit(
        train_gen,
        validation_data=val_gen,
        epochs=100,
        callbacks=callbacks_lst
    )

    return model, history

# 5. Model Saving/Loading
def save_model(model, path='clock_model.h5'):
    model.save(path)

def load_model(path='clock_model.h5'):
    return models.load_model(
        path,
        custom_objects={
            'HourMAE': HourMAE,
            'MinuteMAE': MinuteMAE,
            'SecondMAE': SecondMAE,
            'cyclic_time_loss': cyclic_time_loss
        }
    )

import matplotlib.pyplot as plt
import os

def plot_training(history, save_dir='training_plots', save_name='training_metrics.png',
                 save_format='png', dpi=300, show=True):
    """
    Plot and save training metrics visualization
    """
    # Create directory if needed
    os.makedirs(save_dir, exist_ok=True)

    plt.figure(figsize=(15, 5))

    # Loss plot
    plt.subplot(1, 3, 1)
    plt.plot(history.history['loss'], label='Train')
    plt.plot(history.history['val_loss'], label='Validation')
    plt.title('Loss Curve')
    plt.ylabel('Loss')
    plt.xlabel('Epoch')
    plt.legend()

    # Hour MAE plot
    plt.subplot(1, 3, 2)
    plt.plot(history.history['hour_mae'], label='Train')
    plt.plot(history.history['val_hour_mae'], label='Validation')
    plt.title('Hour MAE')
    plt.ylabel('Hours MAE')
    plt.xlabel('Epoch')
    plt.legend()

    # Minute & Second MAE plot
    plt.subplot(1, 3, 3)
    plt.plot(history.history['minute_mae'], label='Min Train')
    plt.plot(history.history['val_minute_mae'], label='Min Val')
    plt.plot(history.history['second_mae'], label='Sec Train')
    plt.plot(history.history['val_second_mae'], label='Sec Val')
    plt.title('Minute & Second MAE')
    plt.ylabel('MAE')
    plt.xlabel('Epoch')
    plt.legend()

    plt.tight_layout()

    # Save the full figure
    full_path = os.path.join(save_dir, save_name)
    plt.savefig(full_path, format=save_format, dpi=dpi, bbox_inches='tight')

    # Save individual components
    components = {
        'loss': (0, 'loss_curve'),
        'hour_mae': (1, 'hour_mae'),
        'minute_second_mae': (2, 'minute_second_mae')
    }

    for key, (idx, name) in components.items():
        fig = plt.figure(figsize=(5, 4))
        ax = fig.add_subplot(111)
        ax.set_position([0.15, 0.15, 0.75, 0.75])  # Adjust margins

        if key == 'loss':
            ax.plot(history.history['loss'], label='Train')
            ax.plot(history.history['val_loss'], label='Validation')
            ax.set_title('Loss Curve')
            ax.set_ylabel('Loss')
        elif key == 'hour_mae':
            ax.plot(history.history['hour_mae'], label='Train')
            ax.plot(history.history['val_hour_mae'], label='Validation')
            ax.set_title('Hour MAE')
            ax.set_ylabel('Hours MAE')
        else:
            ax.plot(history.history['minute_mae'], label='Min Train')
            ax.plot(history.history['val_minute_mae'], label='Min Val')
            ax.plot(history.history['second_mae'], label='Sec Train')
            ax.plot(history.history['val_second_mae'], label='Sec Val')
            ax.set_title('Minute & Second MAE')
            ax.set_ylabel('MAE')

        ax.set_xlabel('Epoch')
        ax.legend()
        plt.savefig(os.path.join(save_dir, f'{name}.{save_format}'),
                    format=save_format, dpi=dpi)
        plt.close(fig)

    if show:
        plt.show()
    else:
        plt.close()

    print(f"Saved training plots to: {save_dir}")

# 7. Inference
def predict_time(model, image_path, img_size=(224, 224)):
    img = cv2.imread(image_path)
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    img = cv2.resize(img, img_size)
    img = img.astype(np.float32) / 255.0
    img = np.expand_dims(img, axis=0)

    pred = model.predict(img)[0]
    hour = (pred[0] * 12) % 12
    minute = (pred[1] * 60) % 60
    second = (pred[2] * 60) % 60

    return hour, minute, second

# Usage Example
if __name__ == "__main__":
    # Load and prepare data
    train_df = pd.read_csv("/content/artifacts/data_preprocessed/train.csv")
    val_df = pd.read_csv("/content/artifacts/data_preprocessed/val.csv")

    train_gen = CustomDataGenerator(train_df)
    val_gen = CustomDataGenerator(val_df, shuffle=False)

    # Train
    model, history = train_model(train_gen, val_gen)
    plot_training(
          history,
          save_dir='experiment_1_plots',
          save_name='training_metrics.svg',
          save_format='svg',
          dpi=300,
          show=False
      )

    # Save
    save_model(model)

    # Predict
    hour, minute, second = predict_time(model, "/content/artifacts/data_preprocessed/test/10009.png")
    print(f"Predicted Time: {int(hour):02}:{int(minute):02}:{int(second):02}")
# Out:
# Epoch 1/100
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 976/976 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - hour_mae: 3.1034 - loss: 0.0317 - minute_mae: 15.8322 - second_mae: 15.8828
# Epoch 1: val_hour_mae improved from inf to 2.63511, saving model to best_clock_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 976/976 ━━━━━━━━━━━━━━━━━━━━ 116s 108ms/step - hour_mae: 3.1029 - loss: 0.0317 - minute_mae: 15.8301 - second_mae: 15.8817 - val_hour_mae: 2.6351 - val_loss: 0.0271 - val_minute_mae: 13.1207 - val_second_mae: 14.3242 - learning_rate: 0.0010
# Epoch 2/100
# 976/976 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - hour_mae: 2.3269 - loss: 0.0248 - minute_mae: 13.0274 - second_mae: 14.1594
# Epoch 2: val_hour_mae improved from 2.63511 to 2.01068, saving model to best_clock_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 976/976 ━━━━━━━━━━━━━━━━━━━━ 127s 96ms/step - hour_mae: 2.3268 - loss: 0.0248 - minute_mae: 13.0271 - second_mae: 14.1593 - val_hour_mae: 2.0107 - val_loss: 0.0220 - val_minute_mae: 11.8728 - val_second_mae: 13.6324 - learning_rate: 0.0010
# Epoch 3/100
# 976/976 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - hour_mae: 2.1064 - loss: 0.0230 - minute_mae: 12.5592 - second_mae: 13.9561
# Epoch 3: val_hour_mae did not improve from 2.01068
# 976/976 ━━━━━━━━━━━━━━━━━━━━ 93s 96ms/step - hour_mae: 2.1063 - loss: 0.0230 - minute_mae: 12.5591 - second_mae: 13.9561 - val_hour_mae: 2.0516 - val_loss: 0.0220 - val_minute_mae: 11.3860 - val_second_mae: 13.1452 - learning_rate: 0.0010
# Epoch 4/100
# 976/976 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - hour_mae: 2.0179 - loss: 0.0223 - minute_mae: 12.3700 - second_mae: 13.7489
# Epoch 4: val_hour_mae improved from 2.01068 to 1.85839, saving model to best_clock_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 976/976 ━━━━━━━━━━━━━━━━━━━━ 94s 96ms/step - hour_mae: 2.0179 - loss: 0.0223 - minute_mae: 12.3699 - second_mae: 13.7489 - val_hour_mae: 1.8584 - val_loss: 0.0207 - val_minute_mae: 11.3536 - val_second_mae: 13.6829 - learning_rate: 0.0010
# Epoch 5/100
# 976/976 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - hour_mae: 2.0844 - loss: 0.0227 - minute_mae: 12.2096 - second_mae: 13.7412
# Epoch 5: val_hour_mae improved from 1.85839 to 1.65712, saving model to best_clock_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 976/976 ━━━━━━━━━━━━━━━━━━━━ 94s 96ms/step - hour_mae: 2.0844 - loss: 0.0227 - minute_mae: 12.2096 - second_mae: 13.7410 - val_hour_mae: 1.6571 - val_loss: 0.0191 - val_minute_mae: 11.3890 - val_second_mae: 13.2290 - learning_rate: 0.0010
# Epoch 6/100
# 976/976 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - hour_mae: 1.9807 - loss: 0.0218 - minute_mae: 12.2520 - second_mae: 13.3086
# Epoch 6: val_hour_mae did not improve from 1.65712
# 976/976 ━━━━━━━━━━━━━━━━━━━━ 93s 96ms/step - hour_mae: 1.9807 - loss: 0.0218 - minute_mae: 12.2519 - second_mae: 13.3086 - val_hour_mae: 1.6841 - val_loss: 0.0191 - val_minute_mae: 11.5360 - val_second_mae: 12.3680 - learning_rate: 0.0010
# Epoch 7/100
# 976/976 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - hour_mae: 1.9357 - loss: 0.0214 - minute_mae: 12.1657 - second_mae: 13.2136
# Epoch 7: val_hour_mae improved from 1.65712 to 1.64964, saving model to best_clock_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 976/976 ━━━━━━━━━━━━━━━━━━━━ 94s 96ms/step - hour_mae: 1.9356 - loss: 0.0214 - minute_mae: 12.1658 - second_mae: 13.2137 - val_hour_mae: 1.6496 - val_loss: 0.0189 - val_minute_mae: 10.9389 - val_second_mae: 12.9457 - learning_rate: 0.0010
# Epoch 8/100
# 976/976 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - hour_mae: 1.8687 - loss: 0.0210 - minute_mae: 12.1516 - second_mae: 13.2544
# Epoch 8: val_hour_mae improved from 1.64964 to 1.47059, saving model to best_clock_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 976/976 ━━━━━━━━━━━━━━━━━━━━ 94s 96ms/step - hour_mae: 1.8687 - loss: 0.0210 - minute_mae: 12.1516 - second_mae: 13.2544 - val_hour_mae: 1.4706 - val_loss: 0.0177 - val_minute_mae: 11.0402 - val_second_mae: 13.0932 - learning_rate: 0.0010
# Epoch 9/100
# 976/976 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - hour_mae: 1.8278 - loss: 0.0207 - minute_mae: 12.1611 - second_mae: 13.3846
# Epoch 9: val_hour_mae improved from 1.47059 to 1.43862, saving model to best_clock_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 976/976 ━━━━━━━━━━━━━━━━━━━━ 94s 96ms/step - hour_mae: 1.8278 - loss: 0.0207 - minute_mae: 12.1611 - second_mae: 13.3847 - val_hour_mae: 1.4386 - val_loss: 0.0175 - val_minute_mae: 11.2197 - val_second_mae: 13.0974 - learning_rate: 0.0010
# Epoch 10/100
# 976/976 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - hour_mae: 1.7751 - loss: 0.0203 - minute_mae: 12.2280 - second_mae: 13.3922
# Epoch 10: val_hour_mae did not improve from 1.43862
# 976/976 ━━━━━━━━━━━━━━━━━━━━ 94s 96ms/step - hour_mae: 1.7751 - loss: 0.0203 - minute_mae: 12.2280 - second_mae: 13.3922 - val_hour_mae: 1.6121 - val_loss: 0.0188 - val_minute_mae: 11.2668 - val_second_mae: 13.3092 - learning_rate: 0.0010
# Epoch 11/100
# 976/976 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - hour_mae: 1.7379 - loss: 0.0200 - minute_mae: 12.1067 - second_mae: 13.2884
# Epoch 11: val_hour_mae improved from 1.43862 to 1.34695, saving model to best_clock_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 976/976 ━━━━━━━━━━━━━━━━━━━━ 143s 97ms/step - hour_mae: 1.7379 - loss: 0.0200 - minute_mae: 12.1068 - second_mae: 13.2884 - val_hour_mae: 1.3470 - val_loss: 0.0165 - val_minute_mae: 10.6324 - val_second_mae: 12.4486 - learning_rate: 0.0010
# Epoch 12/100
# 976/976 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - hour_mae: 1.7146 - loss: 0.0199 - minute_mae: 12.1797 - second_mae: 13.4204
# Epoch 12: val_hour_mae did not improve from 1.34695
# 976/976 ━━━━━━━━━━━━━━━━━━━━ 94s 96ms/step - hour_mae: 1.7146 - loss: 0.0199 - minute_mae: 12.1797 - second_mae: 13.4204 - val_hour_mae: 1.3799 - val_loss: 0.0168 - val_minute_mae: 10.9620 - val_second_mae: 12.4513 - learning_rate: 0.0010
# Epoch 13/100
# 976/976 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - hour_mae: 1.6452 - loss: 0.0193 - minute_mae: 12.0475 - second_mae: 13.3613
# Epoch 13: val_hour_mae did not improve from 1.34695
# 976/976 ━━━━━━━━━━━━━━━━━━━━ 93s 96ms/step - hour_mae: 1.6452 - loss: 0.0193 - minute_mae: 12.0476 - second_mae: 13.3613 - val_hour_mae: 1.6058 - val_loss: 0.0185 - val_minute_mae: 11.0357 - val_second_mae: 12.5662 - learning_rate: 0.0010
# Epoch 14/100
# 976/976 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - hour_mae: 1.6085 - loss: 0.0191 - minute_mae: 12.2745 - second_mae: 13.3383
# Epoch 14: val_hour_mae did not improve from 1.34695
# 976/976 ━━━━━━━━━━━━━━━━━━━━ 94s 96ms/step - hour_mae: 1.6085 - loss: 0.0191 - minute_mae: 12.2745 - second_mae: 13.3383 - val_hour_mae: 1.4147 - val_loss: 0.0175 - val_minute_mae: 12.2448 - val_second_mae: 12.6882 - learning_rate: 0.0010
# Epoch 15/100
# 976/976 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - hour_mae: 1.6136 - loss: 0.0192 - minute_mae: 12.3184 - second_mae: 13.2466
# Epoch 15: val_hour_mae improved from 1.34695 to 1.13592, saving model to best_clock_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 976/976 ━━━━━━━━━━━━━━━━━━━━ 94s 97ms/step - hour_mae: 1.6135 - loss: 0.0192 - minute_mae: 12.3184 - second_mae: 13.2467 - val_hour_mae: 1.1359 - val_loss: 0.0150 - val_minute_mae: 11.1487 - val_second_mae: 12.1763 - learning_rate: 0.0010
# Epoch 16/100
# 976/976 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - hour_mae: 1.5584 - loss: 0.0187 - minute_mae: 12.1388 - second_mae: 13.1820
# Epoch 16: val_hour_mae did not improve from 1.13592
# 976/976 ━━━━━━━━━━━━━━━━━━━━ 141s 96ms/step - hour_mae: 1.5584 - loss: 0.0187 - minute_mae: 12.1388 - second_mae: 13.1821 - val_hour_mae: 1.3192 - val_loss: 0.0162 - val_minute_mae: 10.7135 - val_second_mae: 12.0352 - learning_rate: 0.0010
# Epoch 17/100
# 976/976 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - hour_mae: 1.5523 - loss: 0.0186 - minute_mae: 12.2103 - second_mae: 13.1117
# Epoch 17: val_hour_mae did not improve from 1.13592
# 976/976 ━━━━━━━━━━━━━━━━━━━━ 100s 103ms/step - hour_mae: 1.5522 - loss: 0.0186 - minute_mae: 12.2103 - second_mae: 13.1116 - val_hour_mae: 1.2089 - val_loss: 0.0157 - val_minute_mae: 11.5194 - val_second_mae: 12.4561 - learning_rate: 0.0010
# Epoch 18/100
# 976/976 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - hour_mae: 1.5249 - loss: 0.0184 - minute_mae: 12.1147 - second_mae: 13.0971
# Epoch 18: val_hour_mae improved from 1.13592 to 1.13582, saving model to best_clock_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 976/976 ━━━━━━━━━━━━━━━━━━━━ 94s 96ms/step - hour_mae: 1.5249 - loss: 0.0184 - minute_mae: 12.1147 - second_mae: 13.0971 - val_hour_mae: 1.1358 - val_loss: 0.0149 - val_minute_mae: 11.0097 - val_second_mae: 11.8812 - learning_rate: 0.0010
# Epoch 19/100
# 976/976 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - hour_mae: 1.5484 - loss: 0.0186 - minute_mae: 12.0779 - second_mae: 13.0574
# Epoch 19: val_hour_mae did not improve from 1.13582
# 976/976 ━━━━━━━━━━━━━━━━━━━━ 93s 96ms/step - hour_mae: 1.5484 - loss: 0.0186 - minute_mae: 12.0779 - second_mae: 13.0573 - val_hour_mae: 1.3929 - val_loss: 0.0168 - val_minute_mae: 11.1394 - val_second_mae: 11.9701 - learning_rate: 0.0010
# Epoch 20/100
# 976/976 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - hour_mae: 1.5240 - loss: 0.0183 - minute_mae: 12.0432 - second_mae: 12.9705
# Epoch 20: val_hour_mae did not improve from 1.13582
# 976/976 ━━━━━━━━━━━━━━━━━━━━ 93s 96ms/step - hour_mae: 1.5240 - loss: 0.0183 - minute_mae: 12.0433 - second_mae: 12.9705 - val_hour_mae: 1.2608 - val_loss: 0.0161 - val_minute_mae: 11.3527 - val_second_mae: 12.5557 - learning_rate: 0.0010
# Epoch 21/100
# 976/976 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - hour_mae: 1.5232 - loss: 0.0183 - minute_mae: 12.0008 - second_mae: 12.8852
# Epoch 21: val_hour_mae improved from 1.13582 to 1.04746, saving model to best_clock_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 976/976 ━━━━━━━━━━━━━━━━━━━━ 94s 96ms/step - hour_mae: 1.5232 - loss: 0.0183 - minute_mae: 12.0008 - second_mae: 12.8851 - val_hour_mae: 1.0475 - val_loss: 0.0142 - val_minute_mae: 10.8176 - val_second_mae: 11.8620 - learning_rate: 0.0010
# Epoch 22/100
# 976/976 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - hour_mae: 1.5003 - loss: 0.0181 - minute_mae: 12.1152 - second_mae: 12.7587
# Epoch 22: val_hour_mae improved from 1.04746 to 1.03959, saving model to best_clock_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 976/976 ━━━━━━━━━━━━━━━━━━━━ 142s 96ms/step - hour_mae: 1.5003 - loss: 0.0181 - minute_mae: 12.1152 - second_mae: 12.7587 - val_hour_mae: 1.0396 - val_loss: 0.0143 - val_minute_mae: 10.8507 - val_second_mae: 12.4074 - learning_rate: 0.0010
# Epoch 23/100
# 976/976 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - hour_mae: 1.4939 - loss: 0.0180 - minute_mae: 11.8435 - second_mae: 12.7700
# Epoch 23: val_hour_mae did not improve from 1.03959
# 976/976 ━━━━━━━━━━━━━━━━━━━━ 93s 96ms/step - hour_mae: 1.4939 - loss: 0.0180 - minute_mae: 11.8435 - second_mae: 12.7699 - val_hour_mae: 1.1217 - val_loss: 0.0148 - val_minute_mae: 10.6326 - val_second_mae: 12.3794 - learning_rate: 0.0010
# Epoch 24/100
# 976/976 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - hour_mae: 1.4865 - loss: 0.0179 - minute_mae: 11.7866 - second_mae: 12.5537
# Epoch 24: val_hour_mae did not improve from 1.03959
# 976/976 ━━━━━━━━━━━━━━━━━━━━ 93s 96ms/step - hour_mae: 1.4866 - loss: 0.0179 - minute_mae: 11.7867 - second_mae: 12.5538 - val_hour_mae: 1.0820 - val_loss: 0.0150 - val_minute_mae: 12.0950 - val_second_mae: 12.5215 - learning_rate: 0.0010
# Epoch 25/100
# 976/976 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - hour_mae: 1.4840 - loss: 0.0179 - minute_mae: 11.9169 - second_mae: 12.5104
# Epoch 25: val_hour_mae improved from 1.03959 to 1.03338, saving model to best_clock_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 976/976 ━━━━━━━━━━━━━━━━━━━━ 143s 97ms/step - hour_mae: 1.4840 - loss: 0.0179 - minute_mae: 11.9169 - second_mae: 12.5104 - val_hour_mae: 1.0334 - val_loss: 0.0138 - val_minute_mae: 10.3355 - val_second_mae: 11.4077 - learning_rate: 0.0010
# Epoch 26/100
# 976/976 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - hour_mae: 1.4837 - loss: 0.0179 - minute_mae: 11.8510 - second_mae: 12.6419
# Epoch 26: val_hour_mae did not improve from 1.03338
# 976/976 ━━━━━━━━━━━━━━━━━━━━ 94s 96ms/step - hour_mae: 1.4837 - loss: 0.0179 - minute_mae: 11.8510 - second_mae: 12.6417 - val_hour_mae: 1.3857 - val_loss: 0.0163 - val_minute_mae: 10.4413 - val_second_mae: 11.2032 - learning_rate: 0.0010
# Epoch 27/100
# 976/976 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - hour_mae: 1.5081 - loss: 0.0180 - minute_mae: 11.7846 - second_mae: 12.4618
# Epoch 27: val_hour_mae improved from 1.03338 to 0.99080, saving model to best_clock_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 976/976 ━━━━━━━━━━━━━━━━━━━━ 150s 104ms/step - hour_mae: 1.5081 - loss: 0.0180 - minute_mae: 11.7845 - second_mae: 12.4619 - val_hour_mae: 0.9908 - val_loss: 0.0135 - val_minute_mae: 10.6801 - val_second_mae: 11.0767 - learning_rate: 0.0010
# Epoch 28/100
# 976/976 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - hour_mae: 1.4684 - loss: 0.0177 - minute_mae: 11.7782 - second_mae: 12.4126
# Epoch 28: val_hour_mae did not improve from 0.99080
# 976/976 ━━━━━━━━━━━━━━━━━━━━ 94s 96ms/step - hour_mae: 1.4684 - loss: 0.0177 - minute_mae: 11.7781 - second_mae: 12.4125 - val_hour_mae: 1.0808 - val_loss: 0.0141 - val_minute_mae: 10.5112 - val_second_mae: 11.0124 - learning_rate: 0.0010
# Epoch 29/100
# 976/976 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - hour_mae: 1.4432 - loss: 0.0175 - minute_mae: 11.8029 - second_mae: 12.2792
# Epoch 29: val_hour_mae did not improve from 0.99080
# 976/976 ━━━━━━━━━━━━━━━━━━━━ 93s 96ms/step - hour_mae: 1.4432 - loss: 0.0175 - minute_mae: 11.8028 - second_mae: 12.2792 - val_hour_mae: 1.0400 - val_loss: 0.0136 - val_minute_mae: 10.1253 - val_second_mae: 10.8620 - learning_rate: 0.0010
# Epoch 30/100
# 976/976 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - hour_mae: 1.4321 - loss: 0.0174 - minute_mae: 11.7470 - second_mae: 12.3631
# Epoch 30: val_hour_mae did not improve from 0.99080
# 976/976 ━━━━━━━━━━━━━━━━━━━━ 94s 97ms/step - hour_mae: 1.4321 - loss: 0.0174 - minute_mae: 11.7470 - second_mae: 12.3630 - val_hour_mae: 1.1744 - val_loss: 0.0149 - val_minute_mae: 11.0109 - val_second_mae: 10.8747 - learning_rate: 0.0010
# Epoch 31/100
# 976/976 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - hour_mae: 1.4557 - loss: 0.0175 - minute_mae: 11.6278 - second_mae: 12.2182
# Epoch 31: val_hour_mae did not improve from 0.99080
# 976/976 ━━━━━━━━━━━━━━━━━━━━ 95s 97ms/step - hour_mae: 1.4557 - loss: 0.0175 - minute_mae: 11.6278 - second_mae: 12.2183 - val_hour_mae: 1.1680 - val_loss: 0.0149 - val_minute_mae: 10.3864 - val_second_mae: 11.6744 - learning_rate: 0.0010
# Epoch 32/100
# 976/976 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - hour_mae: 1.4430 - loss: 0.0174 - minute_mae: 11.6089 - second_mae: 12.1896
# Epoch 32: val_hour_mae did not improve from 0.99080
# 976/976 ━━━━━━━━━━━━━━━━━━━━ 101s 103ms/step - hour_mae: 1.4430 - loss: 0.0174 - minute_mae: 11.6089 - second_mae: 12.1896 - val_hour_mae: 1.1410 - val_loss: 0.0147 - val_minute_mae: 10.3449 - val_second_mae: 11.5884 - learning_rate: 0.0010
# Epoch 33/100
# 976/976 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - hour_mae: 1.3966 - loss: 0.0171 - minute_mae: 11.6239 - second_mae: 12.1064
# Epoch 33: val_hour_mae did not improve from 0.99080
# 976/976 ━━━━━━━━━━━━━━━━━━━━ 94s 97ms/step - hour_mae: 1.3966 - loss: 0.0171 - minute_mae: 11.6237 - second_mae: 12.1064 - val_hour_mae: 1.1291 - val_loss: 0.0143 - val_minute_mae: 10.2502 - val_second_mae: 10.8507 - learning_rate: 2.0000e-04
# Epoch 34/100
# 976/976 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - hour_mae: 1.3843 - loss: 0.0169 - minute_mae: 11.4296 - second_mae: 12.0105
# Epoch 34: val_hour_mae did not improve from 0.99080
# 976/976 ━━━━━━━━━━━━━━━━━━━━ 94s 96ms/step - hour_mae: 1.3843 - loss: 0.0169 - minute_mae: 11.4295 - second_mae: 12.0104 - val_hour_mae: 1.0245 - val_loss: 0.0135 - val_minute_mae: 9.8820 - val_second_mae: 10.9006 - learning_rate: 2.0000e-04
# Epoch 35/100
# 976/976 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - hour_mae: 1.3750 - loss: 0.0167 - minute_mae: 11.3894 - second_mae: 11.7748
# Epoch 35: val_hour_mae did not improve from 0.99080
# 976/976 ━━━━━━━━━━━━━━━━━━━━ 95s 97ms/step - hour_mae: 1.3750 - loss: 0.0167 - minute_mae: 11.3893 - second_mae: 11.7749 - val_hour_mae: 1.2371 - val_loss: 0.0152 - val_minute_mae: 10.5359 - val_second_mae: 10.8443 - learning_rate: 2.0000e-04
# Epoch 36/100
# 976/976 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - hour_mae: 1.3924 - loss: 0.0169 - minute_mae: 11.4301 - second_mae: 11.8897
# Epoch 36: val_hour_mae did not improve from 0.99080
# 976/976 ━━━━━━━━━━━━━━━━━━━━ 94s 97ms/step - hour_mae: 1.3924 - loss: 0.0169 - minute_mae: 11.4301 - second_mae: 11.8898 - val_hour_mae: 1.0167 - val_loss: 0.0134 - val_minute_mae: 10.1551 - val_second_mae: 10.6597 - learning_rate: 2.0000e-04
# Epoch 37/100
# 976/976 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - hour_mae: 1.3682 - loss: 0.0167 - minute_mae: 11.4294 - second_mae: 11.8688
# Epoch 37: val_hour_mae did not improve from 0.99080
# 976/976 ━━━━━━━━━━━━━━━━━━━━ 94s 96ms/step - hour_mae: 1.3683 - loss: 0.0167 - minute_mae: 11.4294 - second_mae: 11.8689 - val_hour_mae: 1.0392 - val_loss: 0.0138 - val_minute_mae: 10.2105 - val_second_mae: 11.1639 - learning_rate: 2.0000e-04
# Epoch 38/100
# 976/976 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - hour_mae: 1.3674 - loss: 0.0166 - minute_mae: 11.2513 - second_mae: 11.7981
# Epoch 38: val_hour_mae did not improve from 0.99080
# 976/976 ━━━━━━━━━━━━━━━━━━━━ 93s 96ms/step - hour_mae: 1.3674 - loss: 0.0166 - minute_mae: 11.2514 - second_mae: 11.7982 - val_hour_mae: 1.0275 - val_loss: 0.0135 - val_minute_mae: 10.0741 - val_second_mae: 10.8674 - learning_rate: 4.0000e-05
# Epoch 39/100
# 976/976 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - hour_mae: 1.3667 - loss: 0.0167 - minute_mae: 11.3122 - second_mae: 11.8561
# Epoch 39: val_hour_mae did not improve from 0.99080
# 976/976 ━━━━━━━━━━━━━━━━━━━━ 94s 97ms/step - hour_mae: 1.3667 - loss: 0.0167 - minute_mae: 11.3122 - second_mae: 11.8561 - val_hour_mae: 1.0865 - val_loss: 0.0140 - val_minute_mae: 10.1877 - val_second_mae: 10.6926 - learning_rate: 4.0000e-05
# Epoch 40/100
# 976/976 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - hour_mae: 1.3589 - loss: 0.0166 - minute_mae: 11.2549 - second_mae: 11.7957
# Epoch 40: val_hour_mae did not improve from 0.99080
# 976/976 ━━━━━━━━━━━━━━━━━━━━ 94s 96ms/step - hour_mae: 1.3589 - loss: 0.0166 - minute_mae: 11.2549 - second_mae: 11.7958 - val_hour_mae: 1.0834 - val_loss: 0.0140 - val_minute_mae: 10.2772 - val_second_mae: 10.7091 - learning_rate: 4.0000e-05
# Epoch 41/100
# 976/976 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - hour_mae: 1.3725 - loss: 0.0167 - minute_mae: 11.3115 - second_mae: 11.8909
# Epoch 41: val_hour_mae did not improve from 0.99080
# 976/976 ━━━━━━━━━━━━━━━━━━━━ 94s 97ms/step - hour_mae: 1.3725 - loss: 0.0167 - minute_mae: 11.3115 - second_mae: 11.8909 - val_hour_mae: 1.0525 - val_loss: 0.0137 - val_minute_mae: 10.0966 - val_second_mae: 10.6963 - learning_rate: 4.0000e-05
# Epoch 42/100
# 976/976 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - hour_mae: 1.3630 - loss: 0.0166 - minute_mae: 11.2724 - second_mae: 11.7779
# Epoch 42: val_hour_mae did not improve from 0.99080
# 976/976 ━━━━━━━━━━━━━━━━━━━━ 101s 103ms/step - hour_mae: 1.3630 - loss: 0.0166 - minute_mae: 11.2724 - second_mae: 11.7779 - val_hour_mae: 1.0743 - val_loss: 0.0139 - val_minute_mae: 10.1222 - val_second_mae: 10.8453 - learning_rate: 4.0000e-05
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Saved training plots to: experiment_1_plots
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step
# Predicted Time: 04:28:39

# %%
# %pwd
# Out:
# 'd:\\Advanced Project\\time-estimation\\notebooks'

# %%
import os
os.chdir("../")

# %%
# %pwd
# Out:
# 'd:\\Advanced Project\\time-estimation'

# %%
from dataclasses import dataclass
from pathlib import Path

# %%
@dataclass(frozen=True)
class ModelTrainingEntity:
    root_dir: Path
    train_csv: Path
    val_csv: Path
    model_performance: Path
    final_model: Path
    checkpoint_model: Path
    img_height: int
    img_width: int
    learning_rate: float
    epochs: int
    batch_size: int

# %%
from timeEstimator.constant import *
from timeEstimator.Utils.common import read_yaml, create_directory

# %%
class ConfigurationManager:
    def __init__(self, params=PARAMS_FILE_PATH, config=CONFIG_FILE_PATH):
        self.params = read_yaml(params)
        self.config = read_yaml(config)

        create_directory([self.config.root_dir])

    def model_training_config(self):
        config = self.config.model_training
        params = self.params
        create_directory([config.root_dir])
        entity = ModelTrainingEntity(
            root_dir = config.root_dir,
            train_csv = config.train_csv,
            val_csv = config.val_csv,
            model_performance = config.model_performance,
            final_model = config.final_model,
            checkpoint_model = config.checkpoint_model,
            img_height = params.img_height,
            img_width = params.img_width,
            learning_rate = params.learning_rate,
            epochs = params.epochs,
            batch_size = params.batch_size
        )

        return entity

# %%
from timeEstimator.model.custom_resnet import create_time_model
from timeEstimator.model.metrics import HourMAE, MinuteMAE, SecondMAE
from timeEstimator.model.loss import cyclic_time_loss
from timeEstimator.Utils.common import CustomDataGenerator
import pandas as pd
import tensorflow as tf

# %%
class ModelTraining:
    def __init__(self, config: ModelTrainingEntity):
        self.config = config

    def train_model(self, train_gen, val_gen, img_size):
        
        model = create_time_model(img_size)

        model.compile(
            optimizer=tf.keras.optimizers.Adam(1e-3),
            loss=cyclic_time_loss,
            metrics=[HourMAE(), MinuteMAE(), SecondMAE()]
        )

        callbacks_lst = [
            tf.keras.callbacks.EarlyStopping(
                patience=15,
                monitor='val_hour_mae',
                mode='min',
                restore_best_weights=True
            ),
            tf.keras.callbacks.ModelCheckpoint(
                self.config.checkpoint_model,
                monitor='val_hour_mae',
                save_best_only=True,
                mode='min',
                verbose=1
            ),
            tf.keras.callbacks.ReduceLROnPlateau(
                monitor='val_hour_mae',
                factor=0.2,
                patience=5,
                mode='min',
                min_lr=1e-6
            )
        ]

        history = model.fit(
            train_gen,
            validation_data=val_gen,
            epochs=self.config.epochs,
            callbacks=callbacks_lst
        )

        return model, history

    def save_model(self, model, path):
        path = self.config.final_model
        model.save(path)

    def model_train(self):
        train_df = pd.read_csv("artifacts/data_preprocessed/train.csv")
        val_df = pd.read_csv("artifacts/data_preprocessed/val.csv")

        train_gen = CustomDataGenerator(df=train_df,batch_size=self.config.batch_size)
        val_gen = CustomDataGenerator(df=val_df, batch_size=self.config.batch_size,shuffle=False)

        # Train
        img_size = (self.config.img_height, self.config.img_width)
        model, history = self.train_model(train_gen, val_gen, img_size)
        self.plot_training(
            history,
            save_dir=self.config.model_performance,
            save_name='training_metrics.svg',
            save_format='svg',
            dpi=300,
            show=False
        )

        # Save
        self.save_model(model)

# %%
try:
    config = ConfigurationManager()
    training_config = config.model_training_config()
    model_training = ModelTraining(training_config)
    model_training.model_train()
except Exception as e:
    raise e
# Out:
# [2025-02-26 12:34:19,078]: INFO: common : Read YAML File: params.yaml
# [2025-02-26 12:34:19,081]: INFO: common : Read YAML File: config\config.yaml
# [2025-02-26 12:34:19,082]: INFO: common : Directory has been Created: artifacts
# [2025-02-26 12:34:19,084]: INFO: common : Directory has been Created: model
# d:\Advanced Project\time-estimation\env\Lib\site-packages\keras\src\trainers\data_adapters\py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/100
#   5/976 ━━━━━━━━━━━━━━━━━━━━ 23:25 1s/step - hour_mae: 14.9618 - loss: 0.1357 - minute_mae: 66.4570 - second_mae: 40.8796
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[40], line 5
#       3     training_config = config.model_training_config()
#       4     model_training = ModelTraining(training_config)
# ----> 5     model_training.model_train()
#       6 except Exception as e:
#       7     raise e
#
# Cell In[39], line 60, in ModelTraining.model_train(self)
#      58 # Train
#      59 img_size = (self.config.img_height, self.config.img_width)
# ---> 60 model, history = self.train_model(train_gen, val_gen, img_size)
#      61 self.plot_training(
#      62     history,
#      63     save_dir=self.config.model_performance,
#    (...)
#      67     show=False
#      68 )
#      70 # Save
#
# Cell In[39], line 38, in ModelTraining.train_model(self, train_gen, val_gen, img_size)
#       9 model.compile(
#      10     optimizer=tf.keras.optimizers.Adam(1e-3),
#      11     loss=cyclic_time_loss,
#      12     metrics=[HourMAE(), MinuteMAE(), SecondMAE()]
#      13 )
#      15 callbacks_lst = [
#      16     tf.keras.callbacks.EarlyStopping(
#      17         patience=15,
#    (...)
#      35     )
#      36 ]
# ---> 38 history = model.fit(
#      39     train_gen,
#      40     validation_data=val_gen,
#      41     epochs=self.config.epochs,
#      42     callbacks=callbacks_lst
#      43 )
#      45 return model, history
#
# File d:\Advanced Project\time-estimation\env\Lib\site-packages\keras\src\utils\traceback_utils.py:117, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     115 filtered_tb = None
#     116 try:
# --> 117     return fn(*args, **kwargs)
#     118 except Exception as e:
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File d:\Advanced Project\time-estimation\env\Lib\site-packages\keras\src\backend\tensorflow\trainer.py:371, in TensorFlowTrainer.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq)
#     369 for step, iterator in epoch_iterator:
#     370     callbacks.on_train_batch_begin(step)
# --> 371     logs = self.train_function(iterator)
#     372     callbacks.on_train_batch_end(step, logs)
#     373     if self.stop_training:
#
# File d:\Advanced Project\time-estimation\env\Lib\site-packages\keras\src\backend\tensorflow\trainer.py:219, in TensorFlowTrainer._make_function.<locals>.function(iterator)
#     215 def function(iterator):
#     216     if isinstance(
#     217         iterator, (tf.data.Iterator, tf.distribute.DistributedIterator)
#     218     ):
# --> 219         opt_outputs = multi_step_on_iterator(iterator)
#     220         if not opt_outputs.has_value():
#     221             raise StopIteration
#
# File d:\Advanced Project\time-estimation\env\Lib\site-packages\tensorflow\python\util\traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File d:\Advanced Project\time-estimation\env\Lib\site-packages\tensorflow\python\eager\polymorphic_function\polymorphic_function.py:833, in Function.__call__(self, *args, **kwds)
#     830 compiler = "xla" if self._jit_compile else "nonXla"
#     832 with OptionalXlaContext(self._jit_compile):
# --> 833   result = self._call(*args, **kwds)
#     835 new_tracing_count = self.experimental_get_tracing_count()
#     836 without_tracing = (tracing_count == new_tracing_count)
#
# File d:\Advanced Project\time-estimation\env\Lib\site-packages\tensorflow\python\eager\polymorphic_function\polymorphic_function.py:878, in Function._call(self, *args, **kwds)
#     875 self._lock.release()
#     876 # In this case we have not created variables on the first call. So we can
#     877 # run the first trace but we should fail if variables are created.
# --> 878 results = tracing_compilation.call_function(
#     879     args, kwds, self._variable_creation_config
#     880 )
#     881 if self._created_variables:
#     882   raise ValueError("Creating variables on a non-first call to a function"
#     883                    " decorated with tf.function.")
#
# File d:\Advanced Project\time-estimation\env\Lib\site-packages\tensorflow\python\eager\polymorphic_function\tracing_compilation.py:139, in call_function(args, kwargs, tracing_options)
#     137 bound_args = function.function_type.bind(*args, **kwargs)
#     138 flat_inputs = function.function_type.unpack_inputs(bound_args)
# --> 139 return function._call_flat(  # pylint: disable=protected-access
#     140     flat_inputs, captured_inputs=function.captured_inputs
#     141 )
#
# File d:\Advanced Project\time-estimation\env\Lib\site-packages\tensorflow\python\eager\polymorphic_function\concrete_function.py:1322, in ConcreteFunction._call_flat(self, tensor_inputs, captured_inputs)
#    1318 possible_gradient_type = gradients_util.PossibleTapeGradientTypes(args)
#    1319 if (possible_gradient_type == gradients_util.POSSIBLE_GRADIENT_TYPES_NONE
#    1320     and executing_eagerly):
#    1321   # No tape is watching; skip to running the function.
# -> 1322   return self._inference_function.call_preflattened(args)
#    1323 forward_backward = self._select_forward_and_backward_functions(
#    1324     args,
#    1325     possible_gradient_type,
#    1326     executing_eagerly)
#    1327 forward_function, args_with_tangents = forward_backward.forward()
#
# File d:\Advanced Project\time-estimation\env\Lib\site-packages\tensorflow\python\eager\polymorphic_function\atomic_function.py:216, in AtomicFunction.call_preflattened(self, args)
#     214 def call_preflattened(self, args: Sequence[core.Tensor]) -> Any:
#     215   """Calls with flattened tensor inputs and returns the structured output."""
# --> 216   flat_outputs = self.call_flat(*args)
#     217   return self.function_type.pack_output(flat_outputs)
#
# File d:\Advanced Project\time-estimation\env\Lib\site-packages\tensorflow\python\eager\polymorphic_function\atomic_function.py:251, in AtomicFunction.call_flat(self, *args)
#     249 with record.stop_recording():
#     250   if self._bound_context.executing_eagerly():
# --> 251     outputs = self._bound_context.call_function(
#     252         self.name,
#     253         list(args),
#     254         len(self.function_type.flat_outputs),
#     255     )
#     256   else:
#     257     outputs = make_call_op_in_graph(
#     258         self,
#     259         list(args),
#     260         self._bound_context.function_call_options.as_attrs(),
#     261     )
#
# File d:\Advanced Project\time-estimation\env\Lib\site-packages\tensorflow\python\eager\context.py:1552, in Context.call_function(self, name, tensor_inputs, num_outputs)
#    1550 cancellation_context = cancellation.context()
#    1551 if cancellation_context is None:
# -> 1552   outputs = execute.execute(
#    1553       name.decode("utf-8"),
#    1554       num_outputs=num_outputs,
#    1555       inputs=tensor_inputs,
#    1556       attrs=attrs,
#    1557       ctx=self,
#    1558   )
#    1559 else:
#    1560   outputs = execute.execute_with_cancellation(
#    1561       name.decode("utf-8"),
#    1562       num_outputs=num_outputs,
#    (...)
#    1566       cancellation_manager=cancellation_context,
#    1567   )
#
# File d:\Advanced Project\time-estimation\env\Lib\site-packages\tensorflow\python\eager\execute.py:53, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      51 try:
#      52   ctx.ensure_initialized()
# ---> 53   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      54                                       inputs, attrs, num_outputs)
#      55 except core._NotOkStatusException as e:
#      56   if name is not None:
#
# KeyboardInterrupt:
